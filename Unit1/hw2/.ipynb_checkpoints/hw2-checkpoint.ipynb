# %% [markdown]
# # Ансамбли. Бустинг.

# %% [markdown]
# ## ЗАДАНИЕ I. ДОПОЛНИТЕЛЬНОЕ
#
# **Дано**: набор данных из системы поискового антиспама.
#
# **Требуется**: сравнить классификаторы, основанные на алгоритмических композициях, с классическими алгоритмами классификации (SVM, логистическая регрессия) и нейросетями (двуслойный персептрон).
#
# 1. Скачать данные и запустить шаблон кода на python:
# ```
# $ python compos.py -h
# $ python compos.py -tr spam.train.txt -te spam.test.txt
# ```
# 2. Подобрать параметры трёх алгоритмических композиций (RF, Adaboost, GBM), чтобы они превосходили по качеству SVM, логистическую регрессию и двуслойный персептрон.
#
# 3. Построить графики качества классификации в зависимости от числа базовых моделей.
#
# 4*. Построить графики качества классификации в зависимости от параметров алгоритмов (XGBoost, dart, LightGBM и CatBoost)

# %% [markdown]
# ### **1.** Пример работы шаблона кода. Качество на SVM, логистической регрессии и двуслойном перцептроне.

# %%
# !python compos.py -h
# Out:
# usage: compos.py [-h] [-tr TRAIN] [-te TEST] [-t TREES] [-fp FEATURES_PERCENT]
#
# Random Forest Tutorial
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -tr TRAIN, --train TRAIN
#                         Train file name
#   -te TEST, --test TEST
#                         Test file name
#   -t TREES, --trees TREES
#                         Number of trees in random forest
#   -fp FEATURES_PERCENT, --features_percent FEATURES_PERCENT
#                         Percent of features in each tree

# %%
# !python compos.py -tr spam.train.txt -te spam.test.txt
# Out:
# Build random forest classifier...
# Build adaboost classifier...
# Build gbm classifier...
# Build svm classifier...
# Random Forest :
#              precision    recall  f1-score   support
#
#         0.0    0.54760   0.87998   0.67509      2033
#         1.0    0.96406   0.81578   0.88374      8023
#
# avg / total    0.87986   0.82876   0.84156     10056
# final score    0.75583   0.84788   0.77942     10056
#
# AdaBoost :
#              precision    recall  f1-score   support
#
#         0.0    0.92398   0.42450   0.58173      2033
#         1.0    0.87174   0.99115   0.92762      8023
#
# avg / total    0.88230   0.87659   0.85769     10056
# final score    0.89786   0.70782   0.75467     10056
#
# Gradient Boosting Machine :
#              precision    recall  f1-score   support
#
#         0.0    0.67793   0.84899   0.75388      2033
#         1.0    0.95912   0.89779   0.92744      8023
#
# avg / total    0.90227   0.88793   0.89235     10056
# final score    0.81852   0.87339   0.84066     10056
#
# SVM :
#              precision    recall  f1-score   support
#
#         0.0    0.76980   0.97541   0.86049      2033
#         1.0    0.99332   0.92609   0.95852      8023
#
# avg / total    0.94813   0.93606   0.93870     10056
# final score    0.88156   0.95075   0.90951     10056

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn import svm

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_recall_fscore_support
from tqdm import tqdm
from sklearn.metrics import f1_score
#from sklearn.utils.multiclass import unique_labels
#from sklearn.decomposition import PCA


from compos import visualize_data, classification_report

# %%
train_data = np.loadtxt("spam.train.txt")
test_data  = np.loadtxt("spam.test.txt")

total_data = np.concatenate(([train_data, test_data]), axis=0)

X_train, y_train = train_data[:, 1:], train_data[:, 0]
X_test, y_test = test_data[:, 1:], test_data[:, 0]

visualize_data(total_data[0::, 1::], len(train_data[:,0]), len(test_data[:,0]))

#number_of_features = len(train_data[0, 1:])

# %%
X_train.shape, X_test.shape
# Out:
# ((7093, 102), (10056, 102))

# %%
number_of_features
# Out:
# 102

# %% [markdown]
# **Логистическая регрессия (параметры были подобраны в предыдущем дз)**

# %%
log_reg = LogisticRegression(random_state=0, C=1.0, l1_ratio=None, penalty='l1',solver='liblinear')
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="Logistic regression"))
# Out:
# f1-score=0.9360198874787389
# Logistic regression :
#              precision    recall  f1-score   support
#
#         0.0    0.68887   0.94638   0.79735      2033
#         1.0    0.98499   0.89169   0.93602      8023
#
# avg / total    0.92512   0.90274   0.90798     10056
# final score    0.83693   0.91904   0.86668     10056

# %% [markdown]
# **SVM**

# %%
svm_clf = svm.SVC(kernel="rbf")
svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="SVM with rbf kernel"))
# Out:
# f1-score=0.9585241566148487
# SVM with rbf kernel :
#              precision    recall  f1-score   support
#
#         0.0    0.76980   0.97541   0.86049      2033
#         1.0    0.99332   0.92609   0.95852      8023
#
# avg / total    0.94813   0.93606   0.93870     10056
# final score    0.88156   0.95075   0.90951     10056

# %% [markdown]
# **Двуслойный перцептрон**

# %%
import torch
from torch.nn import MSELoss, Linear, Sigmoid, Sequential

NN = Sequential(Linear(102, 100), Sigmoid(), Linear(100, 1))

# %%
def train(network, X_train, y_train, n_epoch, lrate):
    losses = []
    loss = MSELoss()
    optimizer = torch.optim.Adam(network.parameters(), lr=lrate)
    for _ in tqdm(range(n_epoch)):
        optimizer.zero_grad()
        out = network(X_train)
        l = loss(out, y_train)
        losses.append(l.detach().numpy())
        l.backward()
        optimizer.step()
    return losses

# %%
losses = train(NN, torch.from_numpy(X_train).float(), torch.from_numpy(y_train[:,np.newaxis]).float(), 400, 0.001)
y_pred = NN(torch.from_numpy(X_test).float())
print("f1-score={}".format(f1_score(y_test, (y_pred.detach().numpy() > 0.5).astype(int))))
print(classification_report(y_test, (y_pred.detach().numpy() > 0.5).astype(int), alg_name="Perceptron"))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 400/400 [00:02<00:00, 178.17it/s]
# f1-score=0.9389823900188446
# Perceptron :
#              precision    recall  f1-score   support
#
#         0.0    0.70335   0.93064   0.80119      2033
#         1.0    0.98086   0.90054   0.93898      8023
#
# avg / total    0.92475   0.90662   0.91112     10056
# final score    0.84210   0.91559   0.87008     10056

# %%
import matplotlib.pyplot as plt
plt.plot(losses)

# %% [markdown]
# ### **2. и 3.** Подброр параметров для RF, Adaboost, GBM. Графики зависимости качества от числа базовых алгоритмов.

# %%
from sklearn.model_selection import GridSearchCV

def find_best_param(params_dict, clf, X, y):

    search = GridSearchCV(clf, param_grid=params, cv=3, n_jobs=-1)
    search.fit(X, y)
    
    return search.best_estimator_

# %% [markdown]
# **Random Forest**

# %%
params = {
        'n_estimators': range(100, 1051, 50),
        'max_features': np.linspace(0.3, 1.0, 3)
    }
RF_best = find_best_param(params, RandomForestClassifier(), X_train, y_train)

# %%
RF_best
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=0.3,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=600,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = RF_best.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="Random Forest"))
# Out:
# f1-score=0.9648922686945501
# Random Forest :
#              precision    recall  f1-score   support
#
#         0.0    0.82166   0.92917   0.87211      2033
#         1.0    0.98144   0.94890   0.96489      8023
#
# avg / total    0.94913   0.94491   0.94614     10056
# final score    0.90155   0.93903   0.91850     10056

# %%
def best_num_estim(clf, X_train, y_train, X_test, y_test, min_est, max_est, step):
    num_est = list(range(min_est, max_est, step))
    f1_scores = []
    best_score = 0
    best_n_est = 0
    best_clf = None
    for i in tqdm(range(min_est, max_est, step)):
        clf = clf.set_params(**{'n_estimators': i})
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        score = f1_score(y_test, y_pred)
        if best_score < score:
            best_score = score
            best_n_est = i
            best_clf = clf
        f1_scores.append(score)
    plt.plot(num_est, f1_scores)
    plt.xlabel('n_estimators')
    plt.ylabel('f1-score')
    plt.title("Tuning of n_estimators parameter")
    return best_clf, f1_scores, best_n_est, best_score

# %%
import matplotlib.pyplot as plt
best_RF, f1_scores, best_n_est, best_score = best_num_estim(RandomForestClassifier(max_features=0.3), X_train, y_train, X_test, y_test, 50, 1151, 50)
best_n_est
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [12:59<00:00, 33.89s/it]
# 150

# %%
print("N-estimators={}".format(best_n_est))
# Out:
# N-estimators=250

# %%
y_pred = best_RF.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="Random Forest"))
# Out:
# f1-score=0.9656698488967568
# Random Forest :
#              precision    recall  f1-score   support
#
#         0.0    0.82935   0.92277   0.87357      2033
#         1.0    0.97986   0.95189   0.96567      8023
#
# avg / total    0.94943   0.94600   0.94705     10056
# final score    0.90461   0.93733   0.91962     10056

# %% [markdown]
# **Adaboost**

# %%
params = {
        'n_estimators': range(50, 601, 50),
        'learning_rate': np.logspace(-2, 0, 3)
    }
ada_best = find_best_param(params, AdaBoostClassifier(), X_train, y_train)

# %%
ada_best
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.1,
#                    n_estimators=600, random_state=None)

# %%
y_pred = ada_best.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="Adaboost"))
# Out:
# f1-score=0.9700055204563578
# Adaboost :
#              precision    recall  f1-score   support
#
#         0.0    0.93468   0.81653   0.87162      2033
#         1.0    0.95495   0.98554   0.97001      8023
#
# avg / total    0.95085   0.95137   0.95012     10056
# final score    0.94482   0.90103   0.92081     10056

# %%
best_ada, f1_scores, best_n_est, best_score = best_num_estim(AdaBoostClassifier(learning_rate=0.1), X_train, y_train, X_test, y_test, 50, 1051, 50)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [06:05<00:00, 17.41s/it]

# %%
print("N-estimators={}".format(best_n_est))
# Out:
# N-estimators=550

# %%
y_pred = best_ada.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="Adaboost"))
# Out:
# f1-score=0.9690900098911969
# Adaboost :
#              precision    recall  f1-score   support
#
#         0.0    0.90279   0.84506   0.87297      2033
#         1.0    0.96136   0.97694   0.96909      8023
#
# avg / total    0.94952   0.95028   0.94966     10056
# final score    0.93207   0.91100   0.92103     10056

# %% [markdown]
# **GBM**

# %%
best_gbm, f1_scores, best_n_est, best_score = best_num_estim(GradientBoostingClassifier(), X_train, y_train, X_test, y_test, 50, 1051, 50)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [12:26<00:00, 35.53s/it]

# %%
print("N-estimators={}".format(best_n_est))
# Out:
# N-estimators=250

# %%
y_pred = best_gbm.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="GBM"))
# Out:
# f1-score=0.9698523892919689
# GBM :
#              precision    recall  f1-score   support
#
#         0.0    0.87088   0.89572   0.88312      2033
#         1.0    0.97338   0.96635   0.96985      8023
#
# avg / total    0.95266   0.95207   0.95232     10056
# final score    0.92213   0.93103   0.92649     10056

# %% [markdown]
# ### xgboost

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)
# Out:
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\xgboost\core.py:383: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +

# %%
# specify parameters via map
param = {'max_depth': 1, 'learning_rate': 0.1,
         'objective': 'binary:logistic'}

f1_scores = []
best_score = 0
best_n_est = 0
best_clf = None
for i in tqdm(range(50, 1001, 50)):
    clf = xgb.train(param, dtrain, i)
    y_pred =np.where(clf.predict(dtest) < 0.5, 0, 1)
    score = f1_score(y_test, y_pred)
    if best_score < score:
        best_score = score
        best_n_est = i
        best_clf = clf
    f1_scores.append(score)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:36<00:00,  1.84s/it]

# %%
num_est = range(50, 1001, 50)
plt.plot(num_est, f1_scores)
plt.xlabel('n_estimators')
plt.ylabel('f1-score')
plt.title("Tuning of n_estimators parameter")
# Out:
# Text(0.5, 1.0, 'Tuning of n_estimators parameter')

# %%
print("N-estimators={}".format(best_n_est))
y_pred = np.where(best_clf.predict(dtest) < 0.5, 0, 1)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="xgboost"))
# Out:
# N-estimators=300
# f1-score=0.9670476653696497
# xgboost :
#              precision    recall  f1-score   support
#
#         0.0    0.95708   0.76783   0.85207      2033
#         1.0    0.94398   0.99128   0.96705      8023
#
# avg / total    0.94663   0.94610   0.94380     10056
# final score    0.95053   0.87955   0.90956     10056

# %% [markdown]
# ### DART

# %%
# specify parameters via map
param = {'booster': 'dart',
         'max_depth': 1, 'learning_rate': 0.1,
         'objective': 'binary:logistic',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'skip_drop': 0.5}

f1_scores = []
best_score = 0
best_n_est = 0
best_clf = None
for i in tqdm(range(50, 1001, 50)):
    clf = xgb.train(param, dtrain, i)
    y_pred =np.where(clf.predict(dtest) < 0.5, 0, 1)
    score = f1_score(y_test, y_pred)
    if best_score < score:
        best_score = score
        best_n_est = i
        best_clf = clf
    f1_scores.append(score)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:02<00:00,  6.14s/it]

# %%
num_est = range(50, 1001, 50)
plt.plot(num_est, f1_scores)
plt.xlabel('n_estimators')
plt.ylabel('f1-score')
plt.title("Tuning of n_estimators parameter")
# Out:
# Text(0.5, 1.0, 'Tuning of n_estimators parameter')

# %%
print("N-estimators={}".format(best_n_est))
y_pred = np.where(best_clf.predict(dtest) < 0.5, 0, 1)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="DART"))
# Out:
# N-estimators=450
# f1-score=0.9669567334023002
# DART :
#              precision    recall  f1-score   support
#
#         0.0    0.95261   0.77127   0.85241      2033
#         1.0    0.94471   0.99028   0.96696      8023
#
# avg / total    0.94631   0.94600   0.94380     10056
# final score    0.94866   0.88078   0.90968     10056

# %% [markdown]
# ### catboost

# %%
from catboost import CatBoostClassifier, Pool
train_data = Pool(data=X_train,
                  label=y_train
                 )
test_data = Pool(data=X_test,
                  label=y_test
                 )

# %%
f1_scores = []
best_score = 0
best_n_est = 0
best_clf = None
for i in tqdm(range(50, 1001, 50)):
    clf = CatBoostClassifier(iterations = i)
    clf.fit(train_data)
    y_pred = clf.predict(test_data)
    score = f1_score(y_test, y_pred)
    if best_score < score:
        best_score = score
        best_n_est = i
        best_clf = clf
    f1_scores.append(score)
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Learning rate set to 0.370922
# 0:	learn: 0.3813814	total: 8.44ms	remaining: 414ms
# 1:	learn: 0.2638992	total: 16.4ms	remaining: 395ms
# 2:	learn: 0.1954211	total: 23.8ms	remaining: 373ms
# 3:	learn: 0.1627364	total: 31ms	remaining: 357ms
# 4:	learn: 0.1456556	total: 38.6ms	remaining: 348ms
# 5:	learn: 0.1298618	total: 46.6ms	remaining: 341ms
# 6:	learn: 0.1161245	total: 53.8ms	remaining: 331ms
# 7:	learn: 0.1087124	total: 61ms	remaining: 320ms
# 8:	learn: 0.1027508	total: 68.7ms	remaining: 313ms
# 9:	learn: 0.0958472	total: 75.6ms	remaining: 302ms
# 10:	learn: 0.0914906	total: 82.9ms	remaining: 294ms
# 11:	learn: 0.0855114	total: 90ms	remaining: 285ms
# 12:	learn: 0.0818254	total: 98.3ms	remaining: 280ms
# 13:	learn: 0.0787274	total: 105ms	remaining: 271ms
# 14:	learn: 0.0740368	total: 112ms	remaining: 261ms
# 15:	learn: 0.0732128	total: 119ms	remaining: 253ms
# 16:	learn: 0.0699331	total: 126ms	remaining: 245ms
# 17:	learn: 0.0671107	total: 134ms	remaining: 238ms
# 18:	learn: 0.0653891	total: 140ms	remaining: 229ms
# 19:	learn: 0.0634678	total: 147ms	remaining: 221ms
# 20:	learn: 0.0603603	total: 154ms	remaining: 213ms
# 21:	learn: 0.0590462	total: 161ms	remaining: 205ms
# 22:	learn: 0.0578568	total: 167ms	remaining: 196ms
# 23:	learn: 0.0548360	total: 174ms	remaining: 188ms
# 24:	learn: 0.0532431	total: 181ms	remaining: 181ms
# 25:	learn: 0.0526517	total: 188ms	remaining: 173ms
# 26:	learn: 0.0507376	total: 195ms	remaining: 166ms
# 27:	learn: 0.0489778	total: 202ms	remaining: 159ms
# 28:	learn: 0.0477097	total: 209ms	remaining: 152ms
# 29:	learn: 0.0468014	total: 216ms	remaining: 144ms
# 30:	learn: 0.0451680	total: 222ms	remaining: 136ms
# 31:	learn: 0.0429494	total: 230ms	remaining: 129ms
# 32:	learn: 0.0428065	total: 236ms	remaining: 122ms
# 33:	learn: 0.0412429	total: 243ms	remaining: 114ms
# 34:	learn: 0.0397277	total: 249ms	remaining: 107ms
# 35:	learn: 0.0396646	total: 256ms	remaining: 99.5ms
# 36:	learn: 0.0378539	total: 262ms	remaining: 92.2ms
# 37:	learn: 0.0371020	total: 269ms	remaining: 84.9ms
# 38:	learn: 0.0355374	total: 276ms	remaining: 77.7ms
# 39:	learn: 0.0338567	total: 282ms	remaining: 70.6ms
# 40:	learn: 0.0332735	total: 289ms	remaining: 63.5ms
# 41:	learn: 0.0321539	total: 296ms	remaining: 56.4ms
# 42:	learn: 0.0319224	total: 303ms	remaining: 49.3ms
# 43:	learn: 0.0308690	total: 310ms	remaining: 42.3ms
# 44:	learn: 0.0303508	total: 317ms	remaining: 35.3ms
# 45:	learn: 0.0297266	total: 324ms	remaining: 28.2ms
# 46:	learn: 0.0294758	total: 331ms	remaining: 21.1ms
# 47:	learn: 0.0294097	total: 338ms	remaining: 14.1ms
# 48:	learn: 0.0289178	total: 344ms	remaining: 7.03ms
# 49:	learn: 0.0278712	total: 351ms	remaining: 0us
#   5%|████▏                                                                              | 1/20 [00:00<00:09,  2.01it/s]
# Learning rate set to 0.196444
# 0:	learn: 0.4898777	total: 9.14ms	remaining: 905ms
# 1:	learn: 0.3672732	total: 17.4ms	remaining: 852ms
# 2:	learn: 0.2851531	total: 25.1ms	remaining: 812ms
# 3:	learn: 0.2369995	total: 39.4ms	remaining: 945ms
# 4:	learn: 0.2079471	total: 46.5ms	remaining: 883ms
# 5:	learn: 0.1875437	total: 53.8ms	remaining: 842ms
# 6:	learn: 0.1732903	total: 60.7ms	remaining: 806ms
# 7:	learn: 0.1619585	total: 68.4ms	remaining: 787ms
# 8:	learn: 0.1501196	total: 76.3ms	remaining: 771ms
# 9:	learn: 0.1396386	total: 84.1ms	remaining: 757ms
# 10:	learn: 0.1317964	total: 91.2ms	remaining: 738ms
# 11:	learn: 0.1260210	total: 98.3ms	remaining: 721ms
# 12:	learn: 0.1200659	total: 106ms	remaining: 707ms
# 13:	learn: 0.1154652	total: 112ms	remaining: 690ms
# 14:	learn: 0.1106459	total: 120ms	remaining: 679ms
# 15:	learn: 0.1078403	total: 127ms	remaining: 665ms
# 16:	learn: 0.1042692	total: 134ms	remaining: 653ms
# 17:	learn: 0.1008615	total: 140ms	remaining: 640ms
# 18:	learn: 0.0964218	total: 148ms	remaining: 632ms
# 19:	learn: 0.0939804	total: 155ms	remaining: 621ms
# 20:	learn: 0.0906326	total: 162ms	remaining: 610ms
# 21:	learn: 0.0878730	total: 169ms	remaining: 600ms
# 22:	learn: 0.0853820	total: 176ms	remaining: 589ms
# 23:	learn: 0.0832610	total: 183ms	remaining: 580ms
# 24:	learn: 0.0805974	total: 190ms	remaining: 570ms
# 25:	learn: 0.0789351	total: 197ms	remaining: 560ms
# 26:	learn: 0.0775350	total: 204ms	remaining: 552ms
# 27:	learn: 0.0759679	total: 211ms	remaining: 543ms
# 28:	learn: 0.0743531	total: 218ms	remaining: 533ms
# 29:	learn: 0.0718202	total: 225ms	remaining: 524ms
# 30:	learn: 0.0703445	total: 232ms	remaining: 515ms
# 31:	learn: 0.0689113	total: 238ms	remaining: 507ms
# 32:	learn: 0.0674308	total: 246ms	remaining: 499ms
# 33:	learn: 0.0666799	total: 253ms	remaining: 492ms
# 34:	learn: 0.0653386	total: 262ms	remaining: 486ms
# 35:	learn: 0.0647482	total: 269ms	remaining: 478ms
# 36:	learn: 0.0634548	total: 276ms	remaining: 469ms
# 37:	learn: 0.0619119	total: 282ms	remaining: 461ms
# 38:	learn: 0.0609694	total: 289ms	remaining: 452ms
# 39:	learn: 0.0595612	total: 296ms	remaining: 444ms
# 40:	learn: 0.0582634	total: 303ms	remaining: 435ms
# 41:	learn: 0.0576372	total: 309ms	remaining: 427ms
# 42:	learn: 0.0560925	total: 316ms	remaining: 419ms
# 43:	learn: 0.0556536	total: 323ms	remaining: 411ms
# 44:	learn: 0.0545756	total: 330ms	remaining: 403ms
# 45:	learn: 0.0539132	total: 336ms	remaining: 395ms
# 46:	learn: 0.0533696	total: 358ms	remaining: 404ms
# 47:	learn: 0.0524371	total: 365ms	remaining: 395ms
# 48:	learn: 0.0516650	total: 372ms	remaining: 387ms
# 49:	learn: 0.0502956	total: 378ms	remaining: 378ms
# 50:	learn: 0.0499230	total: 385ms	remaining: 370ms
# 51:	learn: 0.0494444	total: 392ms	remaining: 362ms
# 52:	learn: 0.0487534	total: 398ms	remaining: 353ms
# 53:	learn: 0.0476358	total: 405ms	remaining: 345ms
# 54:	learn: 0.0474341	total: 412ms	remaining: 337ms
# 55:	learn: 0.0467998	total: 419ms	remaining: 329ms
# 56:	learn: 0.0463297	total: 426ms	remaining: 321ms
# 57:	learn: 0.0457548	total: 433ms	remaining: 314ms
# 58:	learn: 0.0447148	total: 441ms	remaining: 306ms
# 59:	learn: 0.0437710	total: 448ms	remaining: 299ms
# 60:	learn: 0.0432253	total: 455ms	remaining: 291ms
# 61:	learn: 0.0427050	total: 462ms	remaining: 283ms
# 62:	learn: 0.0417840	total: 469ms	remaining: 275ms
# 63:	learn: 0.0414753	total: 476ms	remaining: 268ms
# 64:	learn: 0.0405342	total: 483ms	remaining: 260ms
# 65:	learn: 0.0398202	total: 490ms	remaining: 252ms
# 66:	learn: 0.0395035	total: 497ms	remaining: 245ms
# 67:	learn: 0.0384288	total: 504ms	remaining: 237ms
# 68:	learn: 0.0374861	total: 514ms	remaining: 231ms
# 69:	learn: 0.0373475	total: 522ms	remaining: 224ms
# 70:	learn: 0.0370945	total: 529ms	remaining: 216ms
# 71:	learn: 0.0361559	total: 537ms	remaining: 209ms
# 72:	learn: 0.0358998	total: 545ms	remaining: 201ms
# 73:	learn: 0.0354647	total: 553ms	remaining: 194ms
# 74:	learn: 0.0347703	total: 560ms	remaining: 187ms
# 75:	learn: 0.0341497	total: 568ms	remaining: 179ms
# 76:	learn: 0.0338427	total: 574ms	remaining: 171ms
# 77:	learn: 0.0333796	total: 581ms	remaining: 164ms
# 78:	learn: 0.0322157	total: 589ms	remaining: 156ms
# 79:	learn: 0.0315714	total: 596ms	remaining: 149ms
# 80:	learn: 0.0312710	total: 603ms	remaining: 141ms
# 81:	learn: 0.0312210	total: 610ms	remaining: 134ms
# 82:	learn: 0.0305425	total: 617ms	remaining: 126ms
# 83:	learn: 0.0305271	total: 624ms	remaining: 119ms
# 84:	learn: 0.0304871	total: 632ms	remaining: 112ms
# 85:	learn: 0.0300810	total: 639ms	remaining: 104ms
# 86:	learn: 0.0298749	total: 646ms	remaining: 96.5ms
# 87:	learn: 0.0295280	total: 653ms	remaining: 89ms
# 88:	learn: 0.0287218	total: 660ms	remaining: 81.6ms
# 89:	learn: 0.0281904	total: 666ms	remaining: 74.1ms
# 90:	learn: 0.0279017	total: 673ms	remaining: 66.6ms
# 91:	learn: 0.0273131	total: 680ms	remaining: 59.1ms
# 92:	learn: 0.0270494	total: 686ms	remaining: 51.6ms
# 93:	learn: 0.0266221	total: 693ms	remaining: 44.2ms
# 94:	learn: 0.0263561	total: 699ms	remaining: 36.8ms
# 95:	learn: 0.0260060	total: 706ms	remaining: 29.4ms
# 96:	learn: 0.0257229	total: 712ms	remaining: 22ms
# 97:	learn: 0.0254229	total: 719ms	remaining: 14.7ms
# 98:	learn: 0.0250543	total: 726ms	remaining: 7.33ms
# 99:	learn: 0.0244848	total: 732ms	remaining: 0us
#  10%|████████▎                                                                          | 2/20 [00:01<00:11,  1.61it/s]
# Learning rate set to 0.135445
# 0:	learn: 0.5427028	total: 7.74ms	remaining: 1.15s
# 1:	learn: 0.4351796	total: 15.3ms	remaining: 1.13s
# 2:	learn: 0.3556120	total: 22.4ms	remaining: 1.1s
# 3:	learn: 0.2978240	total: 29.7ms	remaining: 1.08s
# 4:	learn: 0.2666948	total: 36.6ms	remaining: 1.06s
# 5:	learn: 0.2372101	total: 43.7ms	remaining: 1.05s
# 6:	learn: 0.2165662	total: 50.4ms	remaining: 1.03s
# 7:	learn: 0.2027526	total: 57.3ms	remaining: 1.02s
# 8:	learn: 0.1875468	total: 64.4ms	remaining: 1.01s
# 9:	learn: 0.1746849	total: 71.4ms	remaining: 1000ms
# 10:	learn: 0.1639032	total: 78.4ms	remaining: 990ms
# 11:	learn: 0.1536940	total: 85ms	remaining: 977ms
# 12:	learn: 0.1477366	total: 91.6ms	remaining: 966ms
# 13:	learn: 0.1401741	total: 98.4ms	remaining: 955ms
# 14:	learn: 0.1339800	total: 105ms	remaining: 946ms
# 15:	learn: 0.1294766	total: 112ms	remaining: 937ms
# 16:	learn: 0.1265097	total: 118ms	remaining: 926ms
# 17:	learn: 0.1226559	total: 125ms	remaining: 920ms
# 18:	learn: 0.1187631	total: 132ms	remaining: 911ms
# 19:	learn: 0.1154789	total: 139ms	remaining: 902ms
# 20:	learn: 0.1119429	total: 145ms	remaining: 894ms
# 21:	learn: 0.1087116	total: 152ms	remaining: 884ms
# 22:	learn: 0.1059393	total: 159ms	remaining: 876ms
# 23:	learn: 0.1029528	total: 165ms	remaining: 868ms
# 24:	learn: 0.1012772	total: 173ms	remaining: 865ms
# 25:	learn: 0.0986653	total: 180ms	remaining: 859ms
# 26:	learn: 0.0965870	total: 187ms	remaining: 853ms
# 27:	learn: 0.0947280	total: 194ms	remaining: 844ms
# 28:	learn: 0.0924813	total: 200ms	remaining: 836ms
# 29:	learn: 0.0909696	total: 207ms	remaining: 828ms
# 30:	learn: 0.0890728	total: 214ms	remaining: 820ms
# 31:	learn: 0.0870294	total: 220ms	remaining: 812ms
# 32:	learn: 0.0855241	total: 227ms	remaining: 804ms
# 33:	learn: 0.0838001	total: 233ms	remaining: 796ms
# 34:	learn: 0.0822890	total: 240ms	remaining: 788ms
# 35:	learn: 0.0807902	total: 246ms	remaining: 780ms
# 36:	learn: 0.0796094	total: 253ms	remaining: 773ms
# 37:	learn: 0.0785394	total: 259ms	remaining: 765ms
# 38:	learn: 0.0777249	total: 266ms	remaining: 757ms
# 39:	learn: 0.0762841	total: 273ms	remaining: 750ms
# 40:	learn: 0.0751950	total: 279ms	remaining: 742ms
# 41:	learn: 0.0738380	total: 286ms	remaining: 735ms
# 42:	learn: 0.0724259	total: 293ms	remaining: 728ms
# 43:	learn: 0.0715008	total: 299ms	remaining: 721ms
# 44:	learn: 0.0706726	total: 306ms	remaining: 715ms
# 45:	learn: 0.0694634	total: 313ms	remaining: 708ms
# 46:	learn: 0.0685064	total: 320ms	remaining: 702ms
# 47:	learn: 0.0672303	total: 327ms	remaining: 695ms
# 48:	learn: 0.0665061	total: 335ms	remaining: 690ms
# 49:	learn: 0.0655149	total: 342ms	remaining: 684ms
# 50:	learn: 0.0645230	total: 349ms	remaining: 678ms
# 51:	learn: 0.0636467	total: 357ms	remaining: 673ms
# 52:	learn: 0.0631939	total: 364ms	remaining: 667ms
# 53:	learn: 0.0622365	total: 371ms	remaining: 660ms
# 54:	learn: 0.0614577	total: 379ms	remaining: 654ms
# 55:	learn: 0.0608113	total: 386ms	remaining: 648ms
# 56:	learn: 0.0602322	total: 393ms	remaining: 640ms
# 57:	learn: 0.0594872	total: 400ms	remaining: 634ms
# 58:	learn: 0.0580047	total: 406ms	remaining: 627ms
# 59:	learn: 0.0574036	total: 414ms	remaining: 621ms
# 60:	learn: 0.0569895	total: 421ms	remaining: 615ms
# 61:	learn: 0.0561681	total: 428ms	remaining: 608ms
# 62:	learn: 0.0557143	total: 435ms	remaining: 601ms
# 63:	learn: 0.0551913	total: 442ms	remaining: 594ms
# 64:	learn: 0.0545241	total: 449ms	remaining: 587ms
# 65:	learn: 0.0537047	total: 456ms	remaining: 580ms
# 66:	learn: 0.0530943	total: 463ms	remaining: 574ms
# 67:	learn: 0.0526737	total: 470ms	remaining: 567ms
# 68:	learn: 0.0521497	total: 477ms	remaining: 560ms
# 69:	learn: 0.0514721	total: 485ms	remaining: 554ms
# 70:	learn: 0.0507557	total: 491ms	remaining: 547ms
# 71:	learn: 0.0504744	total: 500ms	remaining: 541ms
# 72:	learn: 0.0499485	total: 507ms	remaining: 535ms
# 73:	learn: 0.0494288	total: 515ms	remaining: 529ms
# 74:	learn: 0.0487740	total: 522ms	remaining: 522ms
# 75:	learn: 0.0481886	total: 529ms	remaining: 515ms
# 76:	learn: 0.0477093	total: 537ms	remaining: 509ms
# 77:	learn: 0.0473101	total: 544ms	remaining: 502ms
# 78:	learn: 0.0471723	total: 552ms	remaining: 496ms
# 79:	learn: 0.0467367	total: 559ms	remaining: 489ms
# 80:	learn: 0.0461621	total: 566ms	remaining: 482ms
# 81:	learn: 0.0456338	total: 573ms	remaining: 475ms
# 82:	learn: 0.0451577	total: 580ms	remaining: 468ms
# 83:	learn: 0.0447834	total: 587ms	remaining: 461ms
# 84:	learn: 0.0441355	total: 595ms	remaining: 455ms
# 85:	learn: 0.0439604	total: 601ms	remaining: 448ms
# 86:	learn: 0.0433570	total: 608ms	remaining: 441ms
# 87:	learn: 0.0429892	total: 615ms	remaining: 433ms
# 88:	learn: 0.0423683	total: 623ms	remaining: 427ms
# 89:	learn: 0.0417469	total: 629ms	remaining: 420ms
# 90:	learn: 0.0417039	total: 637ms	remaining: 413ms
# 91:	learn: 0.0413176	total: 644ms	remaining: 406ms
# 92:	learn: 0.0412505	total: 651ms	remaining: 399ms
# 93:	learn: 0.0410451	total: 658ms	remaining: 392ms
# 94:	learn: 0.0405097	total: 665ms	remaining: 385ms
# 95:	learn: 0.0399210	total: 672ms	remaining: 378ms
# 96:	learn: 0.0398602	total: 678ms	remaining: 370ms
# 97:	learn: 0.0393867	total: 685ms	remaining: 363ms
# 98:	learn: 0.0388176	total: 691ms	remaining: 356ms
# 99:	learn: 0.0381657	total: 698ms	remaining: 349ms
# 100:	learn: 0.0373855	total: 705ms	remaining: 342ms
# 101:	learn: 0.0369582	total: 711ms	remaining: 335ms
# 102:	learn: 0.0367613	total: 718ms	remaining: 328ms
# 103:	learn: 0.0362524	total: 725ms	remaining: 321ms
# 104:	learn: 0.0362116	total: 732ms	remaining: 314ms
# 105:	learn: 0.0359733	total: 739ms	remaining: 307ms
# 106:	learn: 0.0354858	total: 746ms	remaining: 300ms
# 107:	learn: 0.0351378	total: 752ms	remaining: 292ms
# 108:	learn: 0.0348676	total: 759ms	remaining: 285ms
# 109:	learn: 0.0345608	total: 765ms	remaining: 278ms
# 110:	learn: 0.0341891	total: 772ms	remaining: 271ms
# 111:	learn: 0.0336452	total: 779ms	remaining: 264ms
# 112:	learn: 0.0333340	total: 786ms	remaining: 257ms
# 113:	learn: 0.0325873	total: 792ms	remaining: 250ms
# 114:	learn: 0.0324486	total: 799ms	remaining: 243ms
# 115:	learn: 0.0321969	total: 805ms	remaining: 236ms
# 116:	learn: 0.0317124	total: 812ms	remaining: 229ms
# 117:	learn: 0.0316827	total: 818ms	remaining: 222ms
# 118:	learn: 0.0313978	total: 825ms	remaining: 215ms
# 119:	learn: 0.0313664	total: 832ms	remaining: 208ms
# 120:	learn: 0.0313396	total: 838ms	remaining: 201ms
# 121:	learn: 0.0308552	total: 845ms	remaining: 194ms
# 122:	learn: 0.0305825	total: 851ms	remaining: 187ms
# 123:	learn: 0.0301798	total: 858ms	remaining: 180ms
# 124:	learn: 0.0301087	total: 864ms	remaining: 173ms
# 125:	learn: 0.0295441	total: 871ms	remaining: 166ms
# 126:	learn: 0.0291764	total: 878ms	remaining: 159ms
# 127:	learn: 0.0285894	total: 884ms	remaining: 152ms
# 128:	learn: 0.0283869	total: 891ms	remaining: 145ms
# 129:	learn: 0.0279425	total: 899ms	remaining: 138ms
# 130:	learn: 0.0278578	total: 905ms	remaining: 131ms
# 131:	learn: 0.0276058	total: 911ms	remaining: 124ms
# 132:	learn: 0.0274842	total: 918ms	remaining: 117ms
# 133:	learn: 0.0270895	total: 925ms	remaining: 110ms
# 134:	learn: 0.0270165	total: 931ms	remaining: 103ms
# 135:	learn: 0.0267611	total: 938ms	remaining: 96.6ms
# 136:	learn: 0.0266430	total: 945ms	remaining: 89.6ms
# 137:	learn: 0.0263558	total: 951ms	remaining: 82.7ms
# 138:	learn: 0.0260825	total: 958ms	remaining: 75.8ms
# 139:	learn: 0.0258071	total: 964ms	remaining: 68.9ms
# 140:	learn: 0.0256881	total: 971ms	remaining: 62ms
# 141:	learn: 0.0254772	total: 977ms	remaining: 55.1ms
# 142:	learn: 0.0252672	total: 984ms	remaining: 48.2ms
# 143:	learn: 0.0248887	total: 991ms	remaining: 41.3ms
# 144:	learn: 0.0248150	total: 997ms	remaining: 34.4ms
# 145:	learn: 0.0247129	total: 1s	remaining: 27.5ms
# 146:	learn: 0.0245893	total: 1.01s	remaining: 20.6ms
# 147:	learn: 0.0243042	total: 1.02s	remaining: 13.7ms
# 148:	learn: 0.0241500	total: 1.02s	remaining: 6.87ms
# 149:	learn: 0.0238607	total: 1.03s	remaining: 0us
#  15%|████████████▍                                                                      | 3/20 [00:02<00:13,  1.25it/s]
# Learning rate set to 0.104038
# 0:	learn: 0.5733895	total: 8.58ms	remaining: 1.71s
# 1:	learn: 0.4740448	total: 15.9ms	remaining: 1.57s
# 2:	learn: 0.4104541	total: 22.9ms	remaining: 1.5s
# 3:	learn: 0.3539700	total: 30.3ms	remaining: 1.49s
# 4:	learn: 0.3102240	total: 37.7ms	remaining: 1.47s
# 5:	learn: 0.2781873	total: 45ms	remaining: 1.45s
# 6:	learn: 0.2545618	total: 52.2ms	remaining: 1.44s
# 7:	learn: 0.2322973	total: 59.3ms	remaining: 1.42s
# 8:	learn: 0.2183902	total: 67.5ms	remaining: 1.43s
# 9:	learn: 0.2051473	total: 74.6ms	remaining: 1.42s
# 10:	learn: 0.1937892	total: 81.3ms	remaining: 1.4s
# 11:	learn: 0.1838677	total: 87.9ms	remaining: 1.38s
# 12:	learn: 0.1758932	total: 94.6ms	remaining: 1.36s
# 13:	learn: 0.1668659	total: 101ms	remaining: 1.34s
# 14:	learn: 0.1601168	total: 108ms	remaining: 1.33s
# 15:	learn: 0.1530561	total: 115ms	remaining: 1.32s
# 16:	learn: 0.1484972	total: 121ms	remaining: 1.3s
# 17:	learn: 0.1439140	total: 128ms	remaining: 1.29s
# 18:	learn: 0.1390884	total: 135ms	remaining: 1.28s
# 19:	learn: 0.1346668	total: 141ms	remaining: 1.27s
# 20:	learn: 0.1316388	total: 148ms	remaining: 1.26s
# 21:	learn: 0.1263937	total: 154ms	remaining: 1.25s
# 22:	learn: 0.1223357	total: 161ms	remaining: 1.24s
# 23:	learn: 0.1196743	total: 168ms	remaining: 1.23s
# 24:	learn: 0.1164324	total: 174ms	remaining: 1.22s
# 25:	learn: 0.1133444	total: 181ms	remaining: 1.21s
# 26:	learn: 0.1104560	total: 189ms	remaining: 1.21s
# 27:	learn: 0.1079321	total: 196ms	remaining: 1.2s
# 28:	learn: 0.1058967	total: 202ms	remaining: 1.19s
# 29:	learn: 0.1040479	total: 209ms	remaining: 1.18s
# 30:	learn: 0.1023619	total: 216ms	remaining: 1.17s
# 31:	learn: 0.1005457	total: 222ms	remaining: 1.17s
# 32:	learn: 0.0987887	total: 229ms	remaining: 1.16s
# 33:	learn: 0.0969929	total: 236ms	remaining: 1.15s
# 34:	learn: 0.0955275	total: 242ms	remaining: 1.14s
# 35:	learn: 0.0941408	total: 249ms	remaining: 1.13s
# 36:	learn: 0.0923024	total: 255ms	remaining: 1.12s
# 37:	learn: 0.0905716	total: 262ms	remaining: 1.11s
# 38:	learn: 0.0892690	total: 268ms	remaining: 1.11s
# 39:	learn: 0.0876948	total: 275ms	remaining: 1.1s
# 40:	learn: 0.0863854	total: 282ms	remaining: 1.09s
# 41:	learn: 0.0857667	total: 288ms	remaining: 1.08s
# 42:	learn: 0.0848536	total: 295ms	remaining: 1.07s
# 43:	learn: 0.0841802	total: 301ms	remaining: 1.07s
# 44:	learn: 0.0835793	total: 308ms	remaining: 1.06s
# 45:	learn: 0.0826618	total: 314ms	remaining: 1.05s
# 46:	learn: 0.0814424	total: 321ms	remaining: 1.04s
# 47:	learn: 0.0801495	total: 328ms	remaining: 1.04s
# 48:	learn: 0.0789006	total: 334ms	remaining: 1.03s
# 49:	learn: 0.0779321	total: 341ms	remaining: 1.02s
# 50:	learn: 0.0770779	total: 348ms	remaining: 1.01s
# 51:	learn: 0.0755240	total: 355ms	remaining: 1.01s
# 52:	learn: 0.0747857	total: 362ms	remaining: 1s
# 53:	learn: 0.0739540	total: 369ms	remaining: 997ms
# 54:	learn: 0.0731306	total: 375ms	remaining: 989ms
# 55:	learn: 0.0720529	total: 383ms	remaining: 985ms
# 56:	learn: 0.0711297	total: 390ms	remaining: 977ms
# 57:	learn: 0.0704529	total: 396ms	remaining: 970ms
# 58:	learn: 0.0697301	total: 403ms	remaining: 962ms
# 59:	learn: 0.0689310	total: 409ms	remaining: 955ms
# 60:	learn: 0.0680990	total: 416ms	remaining: 947ms
# 61:	learn: 0.0674870	total: 422ms	remaining: 940ms
# 62:	learn: 0.0666950	total: 429ms	remaining: 933ms
# 63:	learn: 0.0661576	total: 435ms	remaining: 925ms
# 64:	learn: 0.0656675	total: 442ms	remaining: 918ms
# 65:	learn: 0.0649082	total: 448ms	remaining: 911ms
# 66:	learn: 0.0642623	total: 455ms	remaining: 903ms
# 67:	learn: 0.0637401	total: 474ms	remaining: 920ms
# 68:	learn: 0.0631957	total: 481ms	remaining: 913ms
# 69:	learn: 0.0626982	total: 488ms	remaining: 907ms
# 70:	learn: 0.0621648	total: 496ms	remaining: 901ms
# 71:	learn: 0.0611386	total: 503ms	remaining: 895ms
# 72:	learn: 0.0607782	total: 510ms	remaining: 888ms
# 73:	learn: 0.0602611	total: 518ms	remaining: 881ms
# 74:	learn: 0.0595136	total: 524ms	remaining: 874ms
# 75:	learn: 0.0590617	total: 532ms	remaining: 868ms
# 76:	learn: 0.0585464	total: 539ms	remaining: 861ms
# 77:	learn: 0.0580696	total: 546ms	remaining: 854ms
# 78:	learn: 0.0574805	total: 553ms	remaining: 847ms
# 79:	learn: 0.0569423	total: 559ms	remaining: 839ms
# 80:	learn: 0.0563322	total: 566ms	remaining: 831ms
# 81:	learn: 0.0561213	total: 572ms	remaining: 824ms
# 82:	learn: 0.0560224	total: 579ms	remaining: 816ms
# 83:	learn: 0.0554504	total: 586ms	remaining: 809ms
# 84:	learn: 0.0551694	total: 592ms	remaining: 801ms
# 85:	learn: 0.0546208	total: 599ms	remaining: 793ms
# 86:	learn: 0.0543050	total: 605ms	remaining: 786ms
# 87:	learn: 0.0538543	total: 612ms	remaining: 778ms
# 88:	learn: 0.0533524	total: 618ms	remaining: 771ms
# 89:	learn: 0.0527038	total: 625ms	remaining: 763ms
# 90:	learn: 0.0521319	total: 631ms	remaining: 756ms
# 91:	learn: 0.0518398	total: 638ms	remaining: 749ms
# 92:	learn: 0.0514043	total: 644ms	remaining: 741ms
# 93:	learn: 0.0511155	total: 651ms	remaining: 734ms
# 94:	learn: 0.0506536	total: 657ms	remaining: 726ms
# 95:	learn: 0.0503605	total: 664ms	remaining: 719ms
# 96:	learn: 0.0502307	total: 670ms	remaining: 711ms
# 97:	learn: 0.0498328	total: 677ms	remaining: 704ms
# 98:	learn: 0.0492493	total: 683ms	remaining: 697ms
# 99:	learn: 0.0488573	total: 690ms	remaining: 690ms
# 100:	learn: 0.0482060	total: 696ms	remaining: 682ms
# 101:	learn: 0.0475817	total: 703ms	remaining: 675ms
# 102:	learn: 0.0472235	total: 710ms	remaining: 668ms
# 103:	learn: 0.0468392	total: 717ms	remaining: 662ms
# 104:	learn: 0.0462276	total: 724ms	remaining: 655ms
# 105:	learn: 0.0458808	total: 731ms	remaining: 648ms
# 106:	learn: 0.0454185	total: 737ms	remaining: 641ms
# 107:	learn: 0.0452516	total: 744ms	remaining: 633ms
# 108:	learn: 0.0451538	total: 750ms	remaining: 626ms
# 109:	learn: 0.0447547	total: 757ms	remaining: 619ms
# 110:	learn: 0.0443706	total: 763ms	remaining: 612ms
# 111:	learn: 0.0442626	total: 770ms	remaining: 605ms
# 112:	learn: 0.0439514	total: 776ms	remaining: 598ms
# 113:	learn: 0.0435133	total: 783ms	remaining: 591ms
# 114:	learn: 0.0430313	total: 790ms	remaining: 584ms
# 115:	learn: 0.0426396	total: 796ms	remaining: 576ms
# 116:	learn: 0.0422176	total: 803ms	remaining: 569ms
# 117:	learn: 0.0418169	total: 809ms	remaining: 562ms
# 118:	learn: 0.0414743	total: 816ms	remaining: 555ms
# 119:	learn: 0.0409324	total: 822ms	remaining: 548ms
# 120:	learn: 0.0405970	total: 829ms	remaining: 541ms
# 121:	learn: 0.0400971	total: 835ms	remaining: 534ms
# 122:	learn: 0.0399111	total: 842ms	remaining: 527ms
# 123:	learn: 0.0394875	total: 848ms	remaining: 520ms
# 124:	learn: 0.0388780	total: 855ms	remaining: 513ms
# 125:	learn: 0.0388075	total: 862ms	remaining: 506ms
# 126:	learn: 0.0383702	total: 868ms	remaining: 499ms
# 127:	learn: 0.0383375	total: 874ms	remaining: 492ms
# 128:	learn: 0.0379649	total: 881ms	remaining: 485ms
# 129:	learn: 0.0376570	total: 888ms	remaining: 478ms
# 130:	learn: 0.0372378	total: 894ms	remaining: 471ms
# 131:	learn: 0.0371782	total: 900ms	remaining: 464ms
# 132:	learn: 0.0370339	total: 907ms	remaining: 457ms
# 133:	learn: 0.0368360	total: 915ms	remaining: 451ms
# 134:	learn: 0.0365583	total: 922ms	remaining: 444ms
# 135:	learn: 0.0362077	total: 929ms	remaining: 437ms
# 136:	learn: 0.0357365	total: 935ms	remaining: 430ms
# 137:	learn: 0.0353985	total: 942ms	remaining: 423ms
# 138:	learn: 0.0351773	total: 949ms	remaining: 416ms
# 139:	learn: 0.0347412	total: 956ms	remaining: 410ms
# 140:	learn: 0.0344129	total: 962ms	remaining: 403ms
# 141:	learn: 0.0341192	total: 969ms	remaining: 396ms
# 142:	learn: 0.0337730	total: 976ms	remaining: 389ms
# 143:	learn: 0.0334797	total: 982ms	remaining: 382ms
# 144:	learn: 0.0332610	total: 989ms	remaining: 375ms
# 145:	learn: 0.0328437	total: 995ms	remaining: 368ms
# 146:	learn: 0.0326214	total: 1s	remaining: 361ms
# 147:	learn: 0.0324277	total: 1.01s	remaining: 354ms
# 148:	learn: 0.0321282	total: 1.01s	remaining: 347ms
# 149:	learn: 0.0321004	total: 1.02s	remaining: 340ms
# 150:	learn: 0.0318792	total: 1.03s	remaining: 333ms
# 151:	learn: 0.0316162	total: 1.03s	remaining: 327ms
# 152:	learn: 0.0315895	total: 1.04s	remaining: 320ms
# 153:	learn: 0.0314199	total: 1.05s	remaining: 313ms
# 154:	learn: 0.0310933	total: 1.05s	remaining: 306ms
# 155:	learn: 0.0309346	total: 1.06s	remaining: 299ms
# 156:	learn: 0.0307279	total: 1.07s	remaining: 292ms
# 157:	learn: 0.0305867	total: 1.07s	remaining: 285ms
# 158:	learn: 0.0303722	total: 1.08s	remaining: 279ms
# 159:	learn: 0.0301944	total: 1.09s	remaining: 272ms
# 160:	learn: 0.0297783	total: 1.09s	remaining: 265ms
# 161:	learn: 0.0295419	total: 1.11s	remaining: 260ms
# 162:	learn: 0.0292267	total: 1.11s	remaining: 253ms
# 163:	learn: 0.0289820	total: 1.12s	remaining: 246ms
# 164:	learn: 0.0288078	total: 1.13s	remaining: 239ms
# 165:	learn: 0.0284223	total: 1.13s	remaining: 232ms
# 166:	learn: 0.0282485	total: 1.14s	remaining: 225ms
# 167:	learn: 0.0280911	total: 1.15s	remaining: 219ms
# 168:	learn: 0.0276956	total: 1.15s	remaining: 212ms
# 169:	learn: 0.0274421	total: 1.16s	remaining: 205ms
# 170:	learn: 0.0274207	total: 1.17s	remaining: 198ms
# 171:	learn: 0.0273423	total: 1.17s	remaining: 191ms
# 172:	learn: 0.0270571	total: 1.18s	remaining: 184ms
# 173:	learn: 0.0269007	total: 1.19s	remaining: 177ms
# 174:	learn: 0.0267031	total: 1.19s	remaining: 170ms
# 175:	learn: 0.0265292	total: 1.2s	remaining: 164ms
# 176:	learn: 0.0263506	total: 1.21s	remaining: 157ms
# 177:	learn: 0.0261064	total: 1.21s	remaining: 150ms
# 178:	learn: 0.0257896	total: 1.22s	remaining: 143ms
# 179:	learn: 0.0254399	total: 1.23s	remaining: 136ms
# 180:	learn: 0.0252972	total: 1.23s	remaining: 129ms
# 181:	learn: 0.0251419	total: 1.24s	remaining: 123ms
# 182:	learn: 0.0248737	total: 1.25s	remaining: 116ms
# 183:	learn: 0.0248107	total: 1.25s	remaining: 109ms
# 184:	learn: 0.0246569	total: 1.26s	remaining: 102ms
# 185:	learn: 0.0244575	total: 1.26s	remaining: 95.3ms
# 186:	learn: 0.0244418	total: 1.27s	remaining: 88.5ms
# 187:	learn: 0.0242677	total: 1.28s	remaining: 81.6ms
# 188:	learn: 0.0241732	total: 1.28s	remaining: 74.8ms
# 189:	learn: 0.0239711	total: 1.29s	remaining: 68ms
# 190:	learn: 0.0236873	total: 1.3s	remaining: 61.2ms
# 191:	learn: 0.0234010	total: 1.3s	remaining: 54.4ms
# 192:	learn: 0.0232101	total: 1.31s	remaining: 47.6ms
# 193:	learn: 0.0229877	total: 1.32s	remaining: 40.8ms
# 194:	learn: 0.0227655	total: 1.32s	remaining: 34ms
# 195:	learn: 0.0226698	total: 1.33s	remaining: 27.2ms
# 196:	learn: 0.0226064	total: 1.34s	remaining: 20.4ms
# 197:	learn: 0.0224040	total: 1.34s	remaining: 13.6ms
# 198:	learn: 0.0222692	total: 1.35s	remaining: 6.79ms
# 199:	learn: 0.0222515	total: 1.36s	remaining: 0us
#  20%|████████████████▌                                                                  | 4/20 [00:04<00:16,  1.03s/it]
# Learning rate set to 0.084787
# 0:	learn: 0.5934246	total: 7.71ms	remaining: 1.92s
# 1:	learn: 0.5054412	total: 14.6ms	remaining: 1.81s
# 2:	learn: 0.4308145	total: 21.5ms	remaining: 1.77s
# 3:	learn: 0.3775730	total: 28.4ms	remaining: 1.74s
# 4:	learn: 0.3435878	total: 35.3ms	remaining: 1.73s
# 5:	learn: 0.3089192	total: 42.3ms	remaining: 1.72s
# 6:	learn: 0.2836801	total: 49.2ms	remaining: 1.71s
# 7:	learn: 0.2613223	total: 56ms	remaining: 1.69s
# 8:	learn: 0.2469275	total: 62.7ms	remaining: 1.68s
# 9:	learn: 0.2303428	total: 69.6ms	remaining: 1.67s
# 10:	learn: 0.2171665	total: 76.3ms	remaining: 1.66s
# 11:	learn: 0.2056498	total: 83ms	remaining: 1.65s
# 12:	learn: 0.1972092	total: 89.7ms	remaining: 1.63s
# 13:	learn: 0.1865320	total: 96.3ms	remaining: 1.62s
# 14:	learn: 0.1786606	total: 103ms	remaining: 1.61s
# 15:	learn: 0.1745025	total: 109ms	remaining: 1.6s
# 16:	learn: 0.1680183	total: 116ms	remaining: 1.59s
# 17:	learn: 0.1626172	total: 123ms	remaining: 1.58s
# 18:	learn: 0.1578290	total: 129ms	remaining: 1.57s
# 19:	learn: 0.1517543	total: 136ms	remaining: 1.56s
# 20:	learn: 0.1466517	total: 143ms	remaining: 1.56s
# 21:	learn: 0.1429870	total: 149ms	remaining: 1.55s
# 22:	learn: 0.1399350	total: 156ms	remaining: 1.54s
# 23:	learn: 0.1369422	total: 163ms	remaining: 1.53s
# 24:	learn: 0.1342541	total: 169ms	remaining: 1.52s
# 25:	learn: 0.1312561	total: 176ms	remaining: 1.52s
# 26:	learn: 0.1287521	total: 183ms	remaining: 1.51s
# 27:	learn: 0.1258767	total: 190ms	remaining: 1.51s
# 28:	learn: 0.1240805	total: 197ms	remaining: 1.5s
# 29:	learn: 0.1215642	total: 204ms	remaining: 1.5s
# 30:	learn: 0.1192377	total: 211ms	remaining: 1.49s
# 31:	learn: 0.1172649	total: 217ms	remaining: 1.48s
# 32:	learn: 0.1151795	total: 224ms	remaining: 1.47s
# 33:	learn: 0.1127730	total: 231ms	remaining: 1.47s
# 34:	learn: 0.1109606	total: 237ms	remaining: 1.46s
# 35:	learn: 0.1088614	total: 244ms	remaining: 1.45s
# 36:	learn: 0.1067169	total: 251ms	remaining: 1.44s
# 37:	learn: 0.1047272	total: 257ms	remaining: 1.44s
# 38:	learn: 0.1034403	total: 264ms	remaining: 1.43s
# 39:	learn: 0.1016608	total: 271ms	remaining: 1.42s
# 40:	learn: 0.1005883	total: 278ms	remaining: 1.41s
# 41:	learn: 0.0987492	total: 284ms	remaining: 1.41s
# 42:	learn: 0.0971991	total: 291ms	remaining: 1.4s
# 43:	learn: 0.0959143	total: 298ms	remaining: 1.39s
# 44:	learn: 0.0946553	total: 304ms	remaining: 1.39s
# 45:	learn: 0.0935727	total: 311ms	remaining: 1.38s
# 46:	learn: 0.0919309	total: 317ms	remaining: 1.37s
# 47:	learn: 0.0907183	total: 324ms	remaining: 1.36s
# 48:	learn: 0.0896821	total: 331ms	remaining: 1.36s
# 49:	learn: 0.0884624	total: 338ms	remaining: 1.35s
# 50:	learn: 0.0875742	total: 344ms	remaining: 1.34s
# 51:	learn: 0.0863567	total: 351ms	remaining: 1.33s
# 52:	learn: 0.0854192	total: 357ms	remaining: 1.33s
# 53:	learn: 0.0845568	total: 364ms	remaining: 1.32s
# 54:	learn: 0.0833946	total: 371ms	remaining: 1.32s
# 55:	learn: 0.0824057	total: 378ms	remaining: 1.31s
# 56:	learn: 0.0817075	total: 385ms	remaining: 1.3s
# 57:	learn: 0.0807850	total: 392ms	remaining: 1.3s
# 58:	learn: 0.0798761	total: 398ms	remaining: 1.29s
# 59:	learn: 0.0790385	total: 405ms	remaining: 1.28s
# 60:	learn: 0.0781609	total: 411ms	remaining: 1.27s
# 61:	learn: 0.0773768	total: 418ms	remaining: 1.27s
# 62:	learn: 0.0765176	total: 425ms	remaining: 1.26s
# 63:	learn: 0.0758932	total: 431ms	remaining: 1.25s
# 64:	learn: 0.0752888	total: 438ms	remaining: 1.25s
# 65:	learn: 0.0745292	total: 444ms	remaining: 1.24s
# 66:	learn: 0.0739845	total: 451ms	remaining: 1.23s
# 67:	learn: 0.0732604	total: 458ms	remaining: 1.22s
# 68:	learn: 0.0727967	total: 464ms	remaining: 1.22s
# 69:	learn: 0.0719129	total: 471ms	remaining: 1.21s
# 70:	learn: 0.0712334	total: 477ms	remaining: 1.2s
# 71:	learn: 0.0706443	total: 484ms	remaining: 1.2s
# 72:	learn: 0.0699928	total: 490ms	remaining: 1.19s
# 73:	learn: 0.0696022	total: 497ms	remaining: 1.18s
# 74:	learn: 0.0689713	total: 505ms	remaining: 1.18s
# 75:	learn: 0.0684511	total: 512ms	remaining: 1.17s
# 76:	learn: 0.0680599	total: 519ms	remaining: 1.17s
# 77:	learn: 0.0670686	total: 526ms	remaining: 1.16s
# 78:	learn: 0.0664347	total: 533ms	remaining: 1.15s
# 79:	learn: 0.0657959	total: 540ms	remaining: 1.15s
# 80:	learn: 0.0653842	total: 547ms	remaining: 1.14s
# 81:	learn: 0.0649176	total: 554ms	remaining: 1.14s
# 82:	learn: 0.0644356	total: 561ms	remaining: 1.13s
# 83:	learn: 0.0639329	total: 568ms	remaining: 1.12s
# 84:	learn: 0.0634973	total: 574ms	remaining: 1.11s
# 85:	learn: 0.0632224	total: 581ms	remaining: 1.11s
# 86:	learn: 0.0629393	total: 588ms	remaining: 1.1s
# 87:	learn: 0.0620810	total: 594ms	remaining: 1.09s
# 88:	learn: 0.0614677	total: 601ms	remaining: 1.09s
# 89:	learn: 0.0607866	total: 608ms	remaining: 1.08s
# 90:	learn: 0.0602170	total: 614ms	remaining: 1.07s
# 91:	learn: 0.0599028	total: 621ms	remaining: 1.07s
# 92:	learn: 0.0597275	total: 627ms	remaining: 1.06s
# 93:	learn: 0.0590015	total: 634ms	remaining: 1.05s
# 94:	learn: 0.0586694	total: 641ms	remaining: 1.04s
# 95:	learn: 0.0582874	total: 647ms	remaining: 1.04s
# 96:	learn: 0.0579720	total: 654ms	remaining: 1.03s
# 97:	learn: 0.0573812	total: 660ms	remaining: 1.02s
# 98:	learn: 0.0567189	total: 667ms	remaining: 1.02s
# 99:	learn: 0.0560862	total: 674ms	remaining: 1.01s
# 100:	learn: 0.0553852	total: 680ms	remaining: 1s
# 101:	learn: 0.0549079	total: 687ms	remaining: 997ms
# 102:	learn: 0.0545114	total: 693ms	remaining: 989ms
# 103:	learn: 0.0540372	total: 700ms	remaining: 982ms
# 104:	learn: 0.0534555	total: 707ms	remaining: 976ms
# 105:	learn: 0.0530166	total: 713ms	remaining: 969ms
# 106:	learn: 0.0526409	total: 720ms	remaining: 962ms
# 107:	learn: 0.0521888	total: 727ms	remaining: 956ms
# 108:	learn: 0.0519571	total: 734ms	remaining: 949ms
# 109:	learn: 0.0515672	total: 741ms	remaining: 943ms
# 110:	learn: 0.0511545	total: 747ms	remaining: 936ms
# 111:	learn: 0.0504182	total: 754ms	remaining: 929ms
# 112:	learn: 0.0500343	total: 761ms	remaining: 922ms
# 113:	learn: 0.0496471	total: 767ms	remaining: 916ms
# 114:	learn: 0.0494099	total: 774ms	remaining: 908ms
# 115:	learn: 0.0490378	total: 780ms	remaining: 901ms
# 116:	learn: 0.0485657	total: 787ms	remaining: 895ms
# 117:	learn: 0.0481807	total: 794ms	remaining: 888ms
# 118:	learn: 0.0480769	total: 800ms	remaining: 881ms
# 119:	learn: 0.0477195	total: 807ms	remaining: 874ms
# 120:	learn: 0.0474359	total: 813ms	remaining: 867ms
# 121:	learn: 0.0472205	total: 820ms	remaining: 860ms
# 122:	learn: 0.0470346	total: 826ms	remaining: 853ms
# 123:	learn: 0.0468972	total: 833ms	remaining: 846ms
# 124:	learn: 0.0464817	total: 839ms	remaining: 839ms
# 125:	learn: 0.0463603	total: 846ms	remaining: 833ms
# 126:	learn: 0.0461312	total: 853ms	remaining: 826ms
# 127:	learn: 0.0457417	total: 859ms	remaining: 819ms
# 128:	learn: 0.0453372	total: 866ms	remaining: 812ms
# 129:	learn: 0.0446203	total: 872ms	remaining: 805ms
# 130:	learn: 0.0443518	total: 879ms	remaining: 798ms
# 131:	learn: 0.0443112	total: 885ms	remaining: 791ms
# 132:	learn: 0.0441701	total: 892ms	remaining: 785ms
# 133:	learn: 0.0441313	total: 899ms	remaining: 778ms
# 134:	learn: 0.0438667	total: 906ms	remaining: 772ms
# 135:	learn: 0.0436731	total: 913ms	remaining: 765ms
# 136:	learn: 0.0433233	total: 919ms	remaining: 758ms
# 137:	learn: 0.0426773	total: 926ms	remaining: 752ms
# 138:	learn: 0.0423704	total: 933ms	remaining: 745ms
# 139:	learn: 0.0420873	total: 939ms	remaining: 738ms
# 140:	learn: 0.0416138	total: 946ms	remaining: 731ms
# 141:	learn: 0.0409671	total: 953ms	remaining: 725ms
# 142:	learn: 0.0407457	total: 960ms	remaining: 718ms
# 143:	learn: 0.0405802	total: 966ms	remaining: 711ms
# 144:	learn: 0.0403714	total: 972ms	remaining: 704ms
# 145:	learn: 0.0401129	total: 979ms	remaining: 697ms
# 146:	learn: 0.0399130	total: 986ms	remaining: 691ms
# 147:	learn: 0.0397554	total: 992ms	remaining: 684ms
# 148:	learn: 0.0394831	total: 999ms	remaining: 677ms
# 149:	learn: 0.0394473	total: 1s	remaining: 670ms
# 150:	learn: 0.0388923	total: 1.01s	remaining: 663ms
# 151:	learn: 0.0386852	total: 1.02s	remaining: 657ms
# 152:	learn: 0.0383954	total: 1.02s	remaining: 650ms
# 153:	learn: 0.0379589	total: 1.03s	remaining: 643ms
# 154:	learn: 0.0376144	total: 1.04s	remaining: 637ms
# 155:	learn: 0.0373306	total: 1.04s	remaining: 630ms
# 156:	learn: 0.0370100	total: 1.05s	remaining: 623ms
# 157:	learn: 0.0368113	total: 1.06s	remaining: 616ms
# 158:	learn: 0.0366895	total: 1.06s	remaining: 609ms
# 159:	learn: 0.0364376	total: 1.07s	remaining: 603ms
# 160:	learn: 0.0362071	total: 1.08s	remaining: 596ms
# 161:	learn: 0.0361046	total: 1.08s	remaining: 589ms
# 162:	learn: 0.0357800	total: 1.09s	remaining: 583ms
# 163:	learn: 0.0356765	total: 1.1s	remaining: 576ms
# 164:	learn: 0.0354610	total: 1.1s	remaining: 570ms
# 165:	learn: 0.0354140	total: 1.11s	remaining: 563ms
# 166:	learn: 0.0351235	total: 1.12s	remaining: 556ms
# 167:	learn: 0.0347797	total: 1.13s	remaining: 549ms
# 168:	learn: 0.0344790	total: 1.13s	remaining: 543ms
# 169:	learn: 0.0343242	total: 1.14s	remaining: 536ms
# 170:	learn: 0.0343019	total: 1.15s	remaining: 529ms
# 171:	learn: 0.0340766	total: 1.15s	remaining: 522ms
# 172:	learn: 0.0337371	total: 1.16s	remaining: 516ms
# 173:	learn: 0.0334025	total: 1.16s	remaining: 509ms
# 174:	learn: 0.0332490	total: 1.17s	remaining: 502ms
# 175:	learn: 0.0330907	total: 1.18s	remaining: 495ms
# 176:	learn: 0.0328110	total: 1.18s	remaining: 489ms
# 177:	learn: 0.0326132	total: 1.19s	remaining: 482ms
# 178:	learn: 0.0325009	total: 1.2s	remaining: 475ms
# 179:	learn: 0.0323548	total: 1.2s	remaining: 468ms
# 180:	learn: 0.0320311	total: 1.21s	remaining: 462ms
# 181:	learn: 0.0319268	total: 1.22s	remaining: 455ms
# 182:	learn: 0.0317745	total: 1.22s	remaining: 448ms
# 183:	learn: 0.0315247	total: 1.23s	remaining: 441ms
# 184:	learn: 0.0314545	total: 1.24s	remaining: 435ms
# 185:	learn: 0.0313105	total: 1.24s	remaining: 428ms
# 186:	learn: 0.0311770	total: 1.25s	remaining: 421ms
# 187:	learn: 0.0309765	total: 1.26s	remaining: 414ms
# 188:	learn: 0.0307347	total: 1.26s	remaining: 408ms
# 189:	learn: 0.0306063	total: 1.27s	remaining: 401ms
# 190:	learn: 0.0303752	total: 1.28s	remaining: 395ms
# 191:	learn: 0.0299948	total: 1.28s	remaining: 388ms
# 192:	learn: 0.0297850	total: 1.29s	remaining: 381ms
# 193:	learn: 0.0297106	total: 1.3s	remaining: 375ms
# 194:	learn: 0.0295640	total: 1.3s	remaining: 368ms
# 195:	learn: 0.0293685	total: 1.31s	remaining: 361ms
# 196:	learn: 0.0292677	total: 1.32s	remaining: 354ms
# 197:	learn: 0.0291408	total: 1.32s	remaining: 348ms
# 198:	learn: 0.0289854	total: 1.33s	remaining: 341ms
# 199:	learn: 0.0288874	total: 1.34s	remaining: 334ms
# 200:	learn: 0.0286993	total: 1.34s	remaining: 328ms
# 201:	learn: 0.0285682	total: 1.35s	remaining: 321ms
# 202:	learn: 0.0284205	total: 1.36s	remaining: 314ms
# 203:	learn: 0.0283596	total: 1.36s	remaining: 307ms
# 204:	learn: 0.0282776	total: 1.37s	remaining: 301ms
# 205:	learn: 0.0279956	total: 1.38s	remaining: 294ms
# 206:	learn: 0.0278410	total: 1.38s	remaining: 287ms
# 207:	learn: 0.0277112	total: 1.39s	remaining: 281ms
# 208:	learn: 0.0274774	total: 1.4s	remaining: 274ms
# 209:	learn: 0.0273745	total: 1.4s	remaining: 267ms
# 210:	learn: 0.0272782	total: 1.41s	remaining: 261ms
# 211:	learn: 0.0270880	total: 1.42s	remaining: 254ms
# 212:	learn: 0.0269005	total: 1.42s	remaining: 247ms
# 213:	learn: 0.0267288	total: 1.43s	remaining: 240ms
# 214:	learn: 0.0265367	total: 1.44s	remaining: 234ms
# 215:	learn: 0.0263349	total: 1.44s	remaining: 227ms
# 216:	learn: 0.0262218	total: 1.45s	remaining: 221ms
# 217:	learn: 0.0259966	total: 1.46s	remaining: 214ms
# 218:	learn: 0.0257284	total: 1.46s	remaining: 207ms
# 219:	learn: 0.0254422	total: 1.47s	remaining: 200ms
# 220:	learn: 0.0252908	total: 1.48s	remaining: 194ms
# 221:	learn: 0.0250920	total: 1.48s	remaining: 187ms
# 222:	learn: 0.0250785	total: 1.49s	remaining: 180ms
# 223:	learn: 0.0249335	total: 1.5s	remaining: 174ms
# 224:	learn: 0.0247514	total: 1.5s	remaining: 167ms
# 225:	learn: 0.0246013	total: 1.51s	remaining: 160ms
# 226:	learn: 0.0244005	total: 1.52s	remaining: 154ms
# 227:	learn: 0.0242965	total: 1.52s	remaining: 147ms
# 228:	learn: 0.0241183	total: 1.53s	remaining: 140ms
# 229:	learn: 0.0238290	total: 1.54s	remaining: 134ms
# 230:	learn: 0.0236214	total: 1.54s	remaining: 127ms
# 231:	learn: 0.0234630	total: 1.55s	remaining: 120ms
# 232:	learn: 0.0233458	total: 1.56s	remaining: 114ms
# 233:	learn: 0.0231448	total: 1.56s	remaining: 107ms
# 234:	learn: 0.0231283	total: 1.57s	remaining: 100ms
# 235:	learn: 0.0229815	total: 1.57s	remaining: 93.5ms
# 236:	learn: 0.0227727	total: 1.58s	remaining: 86.8ms
# 237:	learn: 0.0227264	total: 1.59s	remaining: 80.1ms
# 238:	learn: 0.0226487	total: 1.59s	remaining: 73.4ms
# 239:	learn: 0.0224976	total: 1.6s	remaining: 66.8ms
# 240:	learn: 0.0224179	total: 1.61s	remaining: 60.1ms
#  25%|████████████████████▊                                                              | 5/20 [00:06<00:19,  1.28s/it]
# 241:	learn: 0.0221690	total: 1.61s	remaining: 53.4ms
# 242:	learn: 0.0220970	total: 1.62s	remaining: 46.7ms
# 243:	learn: 0.0218866	total: 1.63s	remaining: 40.1ms
# 244:	learn: 0.0216792	total: 1.64s	remaining: 33.4ms
# 245:	learn: 0.0214858	total: 1.64s	remaining: 26.7ms
# 246:	learn: 0.0212070	total: 1.65s	remaining: 20ms
# 247:	learn: 0.0210638	total: 1.66s	remaining: 13.4ms
# 248:	learn: 0.0207746	total: 1.66s	remaining: 6.68ms
# 249:	learn: 0.0207117	total: 1.67s	remaining: 0us
# Learning rate set to 0.071733
# 0:	learn: 0.6075510	total: 9.57ms	remaining: 2.86s
# 1:	learn: 0.5288442	total: 16.5ms	remaining: 2.46s
# 2:	learn: 0.4595227	total: 23.3ms	remaining: 2.31s
# 3:	learn: 0.4101056	total: 30.3ms	remaining: 2.24s
# 4:	learn: 0.3764143	total: 37.2ms	remaining: 2.2s
# 5:	learn: 0.3448813	total: 44.1ms	remaining: 2.16s
# 6:	learn: 0.3183401	total: 51.1ms	remaining: 2.14s
# 7:	learn: 0.2967371	total: 58ms	remaining: 2.12s
# 8:	learn: 0.2746924	total: 65ms	remaining: 2.1s
# 9:	learn: 0.2542238	total: 72ms	remaining: 2.09s
# 10:	learn: 0.2408076	total: 78.8ms	remaining: 2.07s
# 11:	learn: 0.2272366	total: 85.7ms	remaining: 2.06s
# 12:	learn: 0.2176934	total: 92.5ms	remaining: 2.04s
# 13:	learn: 0.2058646	total: 99.3ms	remaining: 2.03s
# 14:	learn: 0.1974931	total: 106ms	remaining: 2.01s
# 15:	learn: 0.1903188	total: 113ms	remaining: 2s
# 16:	learn: 0.1856743	total: 119ms	remaining: 1.99s
# 17:	learn: 0.1797126	total: 126ms	remaining: 1.98s
# 18:	learn: 0.1739378	total: 133ms	remaining: 1.96s
# 19:	learn: 0.1676813	total: 140ms	remaining: 1.95s
# 20:	learn: 0.1623331	total: 146ms	remaining: 1.95s
# 21:	learn: 0.1578132	total: 153ms	remaining: 1.94s
# 22:	learn: 0.1535166	total: 160ms	remaining: 1.93s
# 23:	learn: 0.1495260	total: 167ms	remaining: 1.92s
# 24:	learn: 0.1446450	total: 173ms	remaining: 1.91s
# 25:	learn: 0.1418154	total: 180ms	remaining: 1.9s
# 26:	learn: 0.1388031	total: 187ms	remaining: 1.89s
# 27:	learn: 0.1365093	total: 194ms	remaining: 1.89s
# 28:	learn: 0.1339675	total: 202ms	remaining: 1.89s
# 29:	learn: 0.1317044	total: 208ms	remaining: 1.87s
# 30:	learn: 0.1295659	total: 215ms	remaining: 1.86s
# 31:	learn: 0.1275874	total: 222ms	remaining: 1.86s
# 32:	learn: 0.1254956	total: 229ms	remaining: 1.85s
# 33:	learn: 0.1231430	total: 235ms	remaining: 1.84s
# 34:	learn: 0.1209769	total: 242ms	remaining: 1.83s
# 35:	learn: 0.1187890	total: 249ms	remaining: 1.82s
# 36:	learn: 0.1166722	total: 255ms	remaining: 1.81s
# 37:	learn: 0.1147463	total: 262ms	remaining: 1.81s
# 38:	learn: 0.1132739	total: 269ms	remaining: 1.8s
# 39:	learn: 0.1112469	total: 276ms	remaining: 1.79s
# 40:	learn: 0.1094913	total: 283ms	remaining: 1.78s
# 41:	learn: 0.1076467	total: 289ms	remaining: 1.78s
# 42:	learn: 0.1061203	total: 296ms	remaining: 1.77s
# 43:	learn: 0.1048521	total: 303ms	remaining: 1.76s
# 44:	learn: 0.1034804	total: 309ms	remaining: 1.75s
# 45:	learn: 0.1022306	total: 316ms	remaining: 1.74s
# 46:	learn: 0.1009516	total: 322ms	remaining: 1.74s
# 47:	learn: 0.0991747	total: 329ms	remaining: 1.73s
# 48:	learn: 0.0980559	total: 336ms	remaining: 1.72s
# 49:	learn: 0.0971816	total: 342ms	remaining: 1.71s
# 50:	learn: 0.0963855	total: 349ms	remaining: 1.7s
# 51:	learn: 0.0951344	total: 356ms	remaining: 1.7s
# 52:	learn: 0.0942356	total: 362ms	remaining: 1.69s
# 53:	learn: 0.0934372	total: 369ms	remaining: 1.68s
# 54:	learn: 0.0919336	total: 377ms	remaining: 1.68s
# 55:	learn: 0.0909514	total: 383ms	remaining: 1.67s
# 56:	learn: 0.0899275	total: 390ms	remaining: 1.66s
# 57:	learn: 0.0888719	total: 397ms	remaining: 1.66s
# 58:	learn: 0.0877299	total: 403ms	remaining: 1.65s
# 59:	learn: 0.0869544	total: 410ms	remaining: 1.64s
# 60:	learn: 0.0861150	total: 417ms	remaining: 1.63s
# 61:	learn: 0.0851902	total: 423ms	remaining: 1.62s
# 62:	learn: 0.0843308	total: 430ms	remaining: 1.62s
# 63:	learn: 0.0832606	total: 437ms	remaining: 1.61s
# 64:	learn: 0.0824999	total: 444ms	remaining: 1.6s
# 65:	learn: 0.0815557	total: 450ms	remaining: 1.6s
# 66:	learn: 0.0806042	total: 457ms	remaining: 1.59s
# 67:	learn: 0.0800880	total: 464ms	remaining: 1.58s
# 68:	learn: 0.0794308	total: 470ms	remaining: 1.57s
# 69:	learn: 0.0788481	total: 477ms	remaining: 1.57s
# 70:	learn: 0.0785573	total: 483ms	remaining: 1.56s
# 71:	learn: 0.0779927	total: 490ms	remaining: 1.55s
# 72:	learn: 0.0773691	total: 497ms	remaining: 1.54s
# 73:	learn: 0.0767810	total: 504ms	remaining: 1.54s
# 74:	learn: 0.0760453	total: 511ms	remaining: 1.53s
# 75:	learn: 0.0756401	total: 518ms	remaining: 1.53s
# 76:	learn: 0.0750191	total: 526ms	remaining: 1.52s
# 77:	learn: 0.0740196	total: 532ms	remaining: 1.51s
# 78:	learn: 0.0733467	total: 539ms	remaining: 1.51s
# 79:	learn: 0.0729845	total: 547ms	remaining: 1.5s
# 80:	learn: 0.0723787	total: 554ms	remaining: 1.5s
# 81:	learn: 0.0715537	total: 561ms	remaining: 1.49s
# 82:	learn: 0.0709836	total: 567ms	remaining: 1.48s
# 83:	learn: 0.0704306	total: 574ms	remaining: 1.48s
# 84:	learn: 0.0699657	total: 581ms	remaining: 1.47s
# 85:	learn: 0.0696572	total: 587ms	remaining: 1.46s
# 86:	learn: 0.0693593	total: 594ms	remaining: 1.45s
# 87:	learn: 0.0687968	total: 601ms	remaining: 1.45s
# 88:	learn: 0.0683034	total: 607ms	remaining: 1.44s
# 89:	learn: 0.0677827	total: 614ms	remaining: 1.43s
# 90:	learn: 0.0673763	total: 621ms	remaining: 1.43s
# 91:	learn: 0.0670190	total: 628ms	remaining: 1.42s
# 92:	learn: 0.0665007	total: 634ms	remaining: 1.41s
# 93:	learn: 0.0660508	total: 641ms	remaining: 1.4s
# 94:	learn: 0.0654892	total: 647ms	remaining: 1.4s
# 95:	learn: 0.0651819	total: 654ms	remaining: 1.39s
# 96:	learn: 0.0647452	total: 661ms	remaining: 1.38s
# 97:	learn: 0.0643417	total: 667ms	remaining: 1.38s
# 98:	learn: 0.0636867	total: 674ms	remaining: 1.37s
# 99:	learn: 0.0631377	total: 681ms	remaining: 1.36s
# 100:	learn: 0.0627197	total: 687ms	remaining: 1.35s
# 101:	learn: 0.0623408	total: 694ms	remaining: 1.35s
# 102:	learn: 0.0620412	total: 700ms	remaining: 1.34s
# 103:	learn: 0.0616029	total: 707ms	remaining: 1.33s
# 104:	learn: 0.0611923	total: 714ms	remaining: 1.32s
# 105:	learn: 0.0606826	total: 720ms	remaining: 1.32s
# 106:	learn: 0.0603866	total: 727ms	remaining: 1.31s
# 107:	learn: 0.0599845	total: 734ms	remaining: 1.3s
# 108:	learn: 0.0594454	total: 741ms	remaining: 1.3s
# 109:	learn: 0.0590002	total: 748ms	remaining: 1.29s
# 110:	learn: 0.0586675	total: 755ms	remaining: 1.29s
# 111:	learn: 0.0580358	total: 762ms	remaining: 1.28s
# 112:	learn: 0.0575607	total: 769ms	remaining: 1.27s
# 113:	learn: 0.0572613	total: 775ms	remaining: 1.26s
# 114:	learn: 0.0570537	total: 782ms	remaining: 1.26s
# 115:	learn: 0.0567441	total: 788ms	remaining: 1.25s
# 116:	learn: 0.0563238	total: 795ms	remaining: 1.24s
# 117:	learn: 0.0560407	total: 802ms	remaining: 1.24s
# 118:	learn: 0.0556324	total: 808ms	remaining: 1.23s
# 119:	learn: 0.0552650	total: 815ms	remaining: 1.22s
# 120:	learn: 0.0550595	total: 821ms	remaining: 1.22s
# 121:	learn: 0.0545853	total: 828ms	remaining: 1.21s
# 122:	learn: 0.0541537	total: 835ms	remaining: 1.2s
# 123:	learn: 0.0538013	total: 841ms	remaining: 1.19s
# 124:	learn: 0.0536054	total: 848ms	remaining: 1.19s
# 125:	learn: 0.0532977	total: 854ms	remaining: 1.18s
# 126:	learn: 0.0530508	total: 861ms	remaining: 1.17s
# 127:	learn: 0.0527090	total: 868ms	remaining: 1.17s
# 128:	learn: 0.0523598	total: 874ms	remaining: 1.16s
# 129:	learn: 0.0519660	total: 881ms	remaining: 1.15s
# 130:	learn: 0.0517062	total: 887ms	remaining: 1.14s
# 131:	learn: 0.0513775	total: 894ms	remaining: 1.14s
# 132:	learn: 0.0511041	total: 901ms	remaining: 1.13s
# 133:	learn: 0.0507095	total: 907ms	remaining: 1.12s
# 134:	learn: 0.0503500	total: 915ms	remaining: 1.12s
# 135:	learn: 0.0497345	total: 922ms	remaining: 1.11s
# 136:	learn: 0.0491246	total: 928ms	remaining: 1.1s
# 137:	learn: 0.0487351	total: 935ms	remaining: 1.1s
# 138:	learn: 0.0485821	total: 941ms	remaining: 1.09s
# 139:	learn: 0.0483186	total: 948ms	remaining: 1.08s
# 140:	learn: 0.0480827	total: 955ms	remaining: 1.08s
# 141:	learn: 0.0477534	total: 961ms	remaining: 1.07s
# 142:	learn: 0.0474014	total: 968ms	remaining: 1.06s
# 143:	learn: 0.0470929	total: 975ms	remaining: 1.05s
# 144:	learn: 0.0467780	total: 981ms	remaining: 1.05s
# 145:	learn: 0.0464877	total: 988ms	remaining: 1.04s
# 146:	learn: 0.0462364	total: 994ms	remaining: 1.03s
# 147:	learn: 0.0458731	total: 1s	remaining: 1.03s
# 148:	learn: 0.0451991	total: 1.01s	remaining: 1.02s
# 149:	learn: 0.0451106	total: 1.01s	remaining: 1.01s
# 150:	learn: 0.0447982	total: 1.02s	remaining: 1.01s
# 151:	learn: 0.0446132	total: 1.03s	remaining: 1s
# 152:	learn: 0.0442954	total: 1.03s	remaining: 993ms
# 153:	learn: 0.0440440	total: 1.04s	remaining: 986ms
# 154:	learn: 0.0435835	total: 1.05s	remaining: 980ms
# 155:	learn: 0.0434086	total: 1.05s	remaining: 972ms
# 156:	learn: 0.0430661	total: 1.06s	remaining: 966ms
# 157:	learn: 0.0427380	total: 1.07s	remaining: 959ms
# 158:	learn: 0.0424411	total: 1.07s	remaining: 952ms
# 159:	learn: 0.0421976	total: 1.08s	remaining: 945ms
# 160:	learn: 0.0419911	total: 1.09s	remaining: 938ms
# 161:	learn: 0.0418450	total: 1.09s	remaining: 932ms
# 162:	learn: 0.0417126	total: 1.1s	remaining: 926ms
# 163:	learn: 0.0415083	total: 1.11s	remaining: 919ms
# 164:	learn: 0.0411071	total: 1.11s	remaining: 912ms
# 165:	learn: 0.0408460	total: 1.12s	remaining: 906ms
# ...
# 739:	learn: 0.0269301	total: 5.1s	remaining: 1.79s
# 740:	learn: 0.0269109	total: 5.11s	remaining: 1.78s
# 741:	learn: 0.0268668	total: 5.11s	remaining: 1.78s
# 742:	learn: 0.0268401	total: 5.12s	remaining: 1.77s
# 743:	learn: 0.0267863	total: 5.13s	remaining: 1.76s
# 744:	learn: 0.0267366	total: 5.13s	remaining: 1.76s
# 745:	learn: 0.0267006	total: 5.14s	remaining: 1.75s
# 746:	learn: 0.0266705	total: 5.15s	remaining: 1.74s
# 747:	learn: 0.0266324	total: 5.15s	remaining: 1.74s
# 748:	learn: 0.0266183	total: 5.16s	remaining: 1.73s
# 749:	learn: 0.0265293	total: 5.17s	remaining: 1.72s
# 750:	learn: 0.0265126	total: 5.19s	remaining: 1.72s
# 751:	learn: 0.0264518	total: 5.19s	remaining: 1.71s
# 752:	learn: 0.0264094	total: 5.2s	remaining: 1.71s
# 753:	learn: 0.0263709	total: 5.21s	remaining: 1.7s
# 754:	learn: 0.0263308	total: 5.21s	remaining: 1.69s
# 755:	learn: 0.0262812	total: 5.22s	remaining: 1.68s
# 756:	learn: 0.0262575	total: 5.23s	remaining: 1.68s
# 757:	learn: 0.0262002	total: 5.23s	remaining: 1.67s
# 758:	learn: 0.0261598	total: 5.24s	remaining: 1.66s
# 759:	learn: 0.0261432	total: 5.25s	remaining: 1.66s
# 760:	learn: 0.0261040	total: 5.25s	remaining: 1.65s
# 761:	learn: 0.0260608	total: 5.26s	remaining: 1.64s
# 762:	learn: 0.0259850	total: 5.27s	remaining: 1.64s
# 763:	learn: 0.0259507	total: 5.28s	remaining: 1.63s
# 764:	learn: 0.0258924	total: 5.28s	remaining: 1.62s
# 765:	learn: 0.0258437	total: 5.29s	remaining: 1.62s
# 766:	learn: 0.0258056	total: 5.3s	remaining: 1.61s
# 767:	learn: 0.0257215	total: 5.3s	remaining: 1.6s
# 768:	learn: 0.0256547	total: 5.31s	remaining: 1.59s
# 769:	learn: 0.0256062	total: 5.32s	remaining: 1.59s
# 770:	learn: 0.0255439	total: 5.33s	remaining: 1.58s
# 771:	learn: 0.0255131	total: 5.33s	remaining: 1.57s
# 772:	learn: 0.0255086	total: 5.34s	remaining: 1.57s
# 773:	learn: 0.0255041	total: 5.35s	remaining: 1.56s
# 774:	learn: 0.0254519	total: 5.35s	remaining: 1.55s
# 775:	learn: 0.0254328	total: 5.36s	remaining: 1.55s
# 776:	learn: 0.0253917	total: 5.37s	remaining: 1.54s
# 777:	learn: 0.0253874	total: 5.38s	remaining: 1.53s
# 778:	learn: 0.0253453	total: 5.38s	remaining: 1.53s
# 779:	learn: 0.0252879	total: 5.39s	remaining: 1.52s
# 780:	learn: 0.0252500	total: 5.39s	remaining: 1.51s
# 781:	learn: 0.0251933	total: 5.4s	remaining: 1.51s
# 782:	learn: 0.0251561	total: 5.41s	remaining: 1.5s
# 783:	learn: 0.0251003	total: 5.42s	remaining: 1.49s
# 784:	learn: 0.0250503	total: 5.42s	remaining: 1.49s
# 785:	learn: 0.0250224	total: 5.43s	remaining: 1.48s
# 786:	learn: 0.0250077	total: 5.44s	remaining: 1.47s
# 787:	learn: 0.0249723	total: 5.44s	remaining: 1.46s
# 788:	learn: 0.0249286	total: 5.45s	remaining: 1.46s
# 789:	learn: 0.0248983	total: 5.46s	remaining: 1.45s
# 790:	learn: 0.0248525	total: 5.46s	remaining: 1.44s
# 791:	learn: 0.0248079	total: 5.47s	remaining: 1.44s
# 792:	learn: 0.0247526	total: 5.48s	remaining: 1.43s
# 793:	learn: 0.0246821	total: 5.48s	remaining: 1.42s
# 794:	learn: 0.0246380	total: 5.49s	remaining: 1.42s
# 795:	learn: 0.0245820	total: 5.5s	remaining: 1.41s
# 796:	learn: 0.0245411	total: 5.5s	remaining: 1.4s
# 797:	learn: 0.0245122	total: 5.51s	remaining: 1.4s
# 798:	learn: 0.0244624	total: 5.52s	remaining: 1.39s
# 799:	learn: 0.0244101	total: 5.52s	remaining: 1.38s
# 800:	learn: 0.0243740	total: 5.53s	remaining: 1.37s
# 801:	learn: 0.0243114	total: 5.54s	remaining: 1.37s
# 802:	learn: 0.0243022	total: 5.54s	remaining: 1.36s
# 803:	learn: 0.0242722	total: 5.55s	remaining: 1.35s
# 804:	learn: 0.0242144	total: 5.56s	remaining: 1.35s
# 805:	learn: 0.0241681	total: 5.56s	remaining: 1.34s
# 806:	learn: 0.0241117	total: 5.57s	remaining: 1.33s
# 807:	learn: 0.0240604	total: 5.58s	remaining: 1.32s
# 808:	learn: 0.0240402	total: 5.58s	remaining: 1.32s
# 809:	learn: 0.0240371	total: 5.59s	remaining: 1.31s
# 810:	learn: 0.0240114	total: 5.6s	remaining: 1.3s
# 811:	learn: 0.0239727	total: 5.61s	remaining: 1.3s
# 812:	learn: 0.0239318	total: 5.61s	remaining: 1.29s
# 813:	learn: 0.0239011	total: 5.62s	remaining: 1.28s
# 814:	learn: 0.0238606	total: 5.63s	remaining: 1.28s
# 815:	learn: 0.0238090	total: 5.63s	remaining: 1.27s
# 816:	learn: 0.0237866	total: 5.64s	remaining: 1.26s
# 817:	learn: 0.0237517	total: 5.65s	remaining: 1.26s
# 818:	learn: 0.0237111	total: 5.65s	remaining: 1.25s
# 819:	learn: 0.0236819	total: 5.66s	remaining: 1.24s
# 820:	learn: 0.0236508	total: 5.67s	remaining: 1.24s
# 821:	learn: 0.0236000	total: 5.67s	remaining: 1.23s
# 822:	learn: 0.0235550	total: 5.68s	remaining: 1.22s
# 823:	learn: 0.0235187	total: 5.69s	remaining: 1.21s
# 824:	learn: 0.0234816	total: 5.69s	remaining: 1.21s
# 825:	learn: 0.0234408	total: 5.7s	remaining: 1.2s
# 826:	learn: 0.0234378	total: 5.71s	remaining: 1.19s
# 827:	learn: 0.0234008	total: 5.71s	remaining: 1.19s
# 828:	learn: 0.0233732	total: 5.72s	remaining: 1.18s
# 829:	learn: 0.0233400	total: 5.73s	remaining: 1.17s
# 830:	learn: 0.0233367	total: 5.74s	remaining: 1.17s
# 831:	learn: 0.0233266	total: 5.74s	remaining: 1.16s
# 832:	learn: 0.0232618	total: 5.75s	remaining: 1.15s
# 833:	learn: 0.0232188	total: 5.75s	remaining: 1.15s
# 834:	learn: 0.0231811	total: 5.76s	remaining: 1.14s
# 835:	learn: 0.0231287	total: 5.77s	remaining: 1.13s
# 836:	learn: 0.0230605	total: 5.78s	remaining: 1.12s
# 837:	learn: 0.0230569	total: 5.78s	remaining: 1.12s
# 838:	learn: 0.0230178	total: 5.79s	remaining: 1.11s
# 839:	learn: 0.0229812	total: 5.8s	remaining: 1.1s
# 840:	learn: 0.0229502	total: 5.8s	remaining: 1.1s
# 841:	learn: 0.0229201	total: 5.81s	remaining: 1.09s
# 842:	learn: 0.0228525	total: 5.82s	remaining: 1.08s
# 843:	learn: 0.0227972	total: 5.82s	remaining: 1.08s
# 844:	learn: 0.0227570	total: 5.83s	remaining: 1.07s
# 845:	learn: 0.0227087	total: 5.84s	remaining: 1.06s
# 846:	learn: 0.0226774	total: 5.84s	remaining: 1.05s
# 847:	learn: 0.0226527	total: 5.85s	remaining: 1.05s
# 848:	learn: 0.0226075	total: 5.86s	remaining: 1.04s
# 849:	learn: 0.0225676	total: 5.87s	remaining: 1.03s
# 850:	learn: 0.0225501	total: 5.87s	remaining: 1.03s
# 851:	learn: 0.0224881	total: 5.88s	remaining: 1.02s
# 852:	learn: 0.0224623	total: 5.88s	remaining: 1.01s
# 853:	learn: 0.0224286	total: 5.89s	remaining: 1.01s
# 854:	learn: 0.0224259	total: 5.9s	remaining: 1s
# 855:	learn: 0.0224233	total: 5.91s	remaining: 993ms
# 856:	learn: 0.0223792	total: 5.91s	remaining: 986ms
# 857:	learn: 0.0223405	total: 5.92s	remaining: 979ms
# 858:	learn: 0.0222830	total: 5.92s	remaining: 973ms
# 859:	learn: 0.0222422	total: 5.93s	remaining: 966ms
# 860:	learn: 0.0222050	total: 5.94s	remaining: 959ms
# 861:	learn: 0.0221553	total: 5.95s	remaining: 952ms
# 862:	learn: 0.0221065	total: 5.95s	remaining: 945ms
# 863:	learn: 0.0220897	total: 5.96s	remaining: 938ms
# 864:	learn: 0.0220633	total: 5.96s	remaining: 931ms
# 865:	learn: 0.0220431	total: 5.99s	remaining: 926ms
# 866:	learn: 0.0220056	total: 5.99s	remaining: 919ms
# 867:	learn: 0.0219619	total: 6s	remaining: 912ms
# 868:	learn: 0.0219275	total: 6.01s	remaining: 906ms
# 869:	learn: 0.0218961	total: 6.01s	remaining: 899ms
# 870:	learn: 0.0218552	total: 6.02s	remaining: 892ms
# 871:	learn: 0.0218225	total: 6.03s	remaining: 886ms
# 872:	learn: 0.0218051	total: 6.04s	remaining: 879ms
# 873:	learn: 0.0217259	total: 6.05s	remaining: 872ms
# 874:	learn: 0.0217006	total: 6.05s	remaining: 865ms
# 875:	learn: 0.0216631	total: 6.06s	remaining: 858ms
# 876:	learn: 0.0216301	total: 6.07s	remaining: 851ms
# 877:	learn: 0.0216158	total: 6.07s	remaining: 844ms
# 878:	learn: 0.0215914	total: 6.08s	remaining: 837ms
# 879:	learn: 0.0215755	total: 6.09s	remaining: 830ms
# 880:	learn: 0.0215541	total: 6.09s	remaining: 823ms
# 881:	learn: 0.0215232	total: 6.1s	remaining: 816ms
# 882:	learn: 0.0214913	total: 6.11s	remaining: 809ms
# 883:	learn: 0.0214541	total: 6.11s	remaining: 802ms
# 884:	learn: 0.0214294	total: 6.12s	remaining: 795ms
# 885:	learn: 0.0214061	total: 6.13s	remaining: 788ms
# 886:	learn: 0.0213966	total: 6.13s	remaining: 781ms
# 887:	learn: 0.0213711	total: 6.14s	remaining: 774ms
# 888:	learn: 0.0213430	total: 6.15s	remaining: 768ms
# 889:	learn: 0.0212885	total: 6.15s	remaining: 761ms
# 890:	learn: 0.0212785	total: 6.16s	remaining: 754ms
# 891:	learn: 0.0212765	total: 6.17s	remaining: 747ms
# 892:	learn: 0.0212678	total: 6.17s	remaining: 740ms
# 893:	learn: 0.0212404	total: 6.18s	remaining: 733ms
# 894:	learn: 0.0212002	total: 6.19s	remaining: 726ms
# 895:	learn: 0.0211669	total: 6.19s	remaining: 719ms
# 896:	learn: 0.0211273	total: 6.2s	remaining: 712ms
# 897:	learn: 0.0210695	total: 6.21s	remaining: 705ms
# 898:	learn: 0.0210292	total: 6.21s	remaining: 698ms
# 899:	learn: 0.0210085	total: 6.22s	remaining: 691ms
# 900:	learn: 0.0209802	total: 6.23s	remaining: 684ms
# 901:	learn: 0.0209263	total: 6.23s	remaining: 677ms
# 902:	learn: 0.0209026	total: 6.24s	remaining: 670ms
# 903:	learn: 0.0208668	total: 6.25s	remaining: 664ms
# 904:	learn: 0.0208266	total: 6.25s	remaining: 657ms
# 905:	learn: 0.0207632	total: 6.26s	remaining: 650ms
# 906:	learn: 0.0207154	total: 6.27s	remaining: 643ms
# 907:	learn: 0.0206894	total: 6.28s	remaining: 636ms
# 908:	learn: 0.0206525	total: 6.28s	remaining: 629ms
# 909:	learn: 0.0206163	total: 6.29s	remaining: 622ms
# 910:	learn: 0.0205933	total: 6.3s	remaining: 615ms
# 911:	learn: 0.0205590	total: 6.3s	remaining: 608ms
# 912:	learn: 0.0205340	total: 6.31s	remaining: 601ms
# 913:	learn: 0.0204871	total: 6.32s	remaining: 595ms
# 914:	learn: 0.0204236	total: 6.33s	remaining: 588ms
# 915:	learn: 0.0204034	total: 6.33s	remaining: 581ms
# 916:	learn: 0.0203833	total: 6.34s	remaining: 574ms
# 917:	learn: 0.0203502	total: 6.35s	remaining: 567ms
# 918:	learn: 0.0203170	total: 6.35s	remaining: 560ms
# 919:	learn: 0.0202903	total: 6.36s	remaining: 553ms
# 920:	learn: 0.0202495	total: 6.37s	remaining: 546ms
# 921:	learn: 0.0202418	total: 6.37s	remaining: 539ms
# 922:	learn: 0.0202211	total: 6.38s	remaining: 532ms
# 923:	learn: 0.0201885	total: 6.39s	remaining: 525ms
# 924:	learn: 0.0201863	total: 6.39s	remaining: 518ms
# 925:	learn: 0.0201556	total: 6.4s	remaining: 511ms
# 926:	learn: 0.0201301	total: 6.41s	remaining: 505ms
# 927:	learn: 0.0200996	total: 6.41s	remaining: 498ms
# 928:	learn: 0.0200914	total: 6.42s	remaining: 491ms
# 929:	learn: 0.0200696	total: 6.43s	remaining: 484ms
# 930:	learn: 0.0200407	total: 6.43s	remaining: 477ms
# 931:	learn: 0.0200203	total: 6.44s	remaining: 470ms
# 932:	learn: 0.0199900	total: 6.45s	remaining: 463ms
# 933:	learn: 0.0199560	total: 6.45s	remaining: 456ms
# 934:	learn: 0.0199144	total: 6.46s	remaining: 449ms
# 935:	learn: 0.0198603	total: 6.47s	remaining: 442ms
# 936:	learn: 0.0198048	total: 6.47s	remaining: 435ms
# 937:	learn: 0.0197647	total: 6.48s	remaining: 428ms
# 938:	learn: 0.0197139	total: 6.49s	remaining: 422ms
# 939:	learn: 0.0196751	total: 6.5s	remaining: 415ms
# 940:	learn: 0.0196565	total: 6.5s	remaining: 408ms
# 941:	learn: 0.0196231	total: 6.51s	remaining: 401ms
# 942:	learn: 0.0196041	total: 6.52s	remaining: 394ms
# 943:	learn: 0.0195633	total: 6.53s	remaining: 387ms
# 944:	learn: 0.0195279	total: 6.53s	remaining: 380ms
# 945:	learn: 0.0195230	total: 6.54s	remaining: 373ms
# 946:	learn: 0.0194905	total: 6.55s	remaining: 366ms
# 947:	learn: 0.0194584	total: 6.55s	remaining: 360ms
# 948:	learn: 0.0194076	total: 6.56s	remaining: 353ms
# 949:	learn: 0.0193822	total: 6.57s	remaining: 346ms
# 950:	learn: 0.0193412	total: 6.57s	remaining: 339ms
# 951:	learn: 0.0193212	total: 6.58s	remaining: 332ms
# 952:	learn: 0.0192897	total: 6.59s	remaining: 325ms
# 953:	learn: 0.0192514	total: 6.59s	remaining: 318ms
# 954:	learn: 0.0192218	total: 6.6s	remaining: 311ms
# 955:	learn: 0.0191922	total: 6.61s	remaining: 304ms
# 956:	learn: 0.0191827	total: 6.62s	remaining: 297ms
# 957:	learn: 0.0191682	total: 6.62s	remaining: 290ms
# 958:	learn: 0.0191453	total: 6.63s	remaining: 283ms
# 959:	learn: 0.0190899	total: 6.63s	remaining: 276ms
# 960:	learn: 0.0190485	total: 6.64s	remaining: 270ms
# 961:	learn: 0.0190324	total: 6.65s	remaining: 263ms
# 962:	learn: 0.0189849	total: 6.65s	remaining: 256ms
# 963:	learn: 0.0189584	total: 6.66s	remaining: 249ms
# 964:	learn: 0.0189308	total: 6.67s	remaining: 242ms
# 965:	learn: 0.0189088	total: 6.67s	remaining: 235ms
# 966:	learn: 0.0188833	total: 6.68s	remaining: 228ms
# 967:	learn: 0.0188486	total: 6.69s	remaining: 221ms
# 968:	learn: 0.0188224	total: 6.69s	remaining: 214ms
# 969:	learn: 0.0187977	total: 6.7s	remaining: 207ms
# 970:	learn: 0.0187756	total: 6.71s	remaining: 200ms
# 971:	learn: 0.0187692	total: 6.72s	remaining: 193ms
# 972:	learn: 0.0187031	total: 6.72s	remaining: 187ms
# 973:	learn: 0.0186639	total: 6.73s	remaining: 180ms
# 974:	learn: 0.0186583	total: 6.74s	remaining: 173ms
# 975:	learn: 0.0186275	total: 6.74s	remaining: 166ms
# 976:	learn: 0.0185996	total: 6.75s	remaining: 159ms
# 977:	learn: 0.0185798	total: 6.76s	remaining: 152ms
# 978:	learn: 0.0185241	total: 6.76s	remaining: 145ms
# 979:	learn: 0.0185178	total: 6.77s	remaining: 138ms
# 980:	learn: 0.0185002	total: 6.78s	remaining: 131ms
# 981:	learn: 0.0184544	total: 6.78s	remaining: 124ms
# 982:	learn: 0.0183894	total: 6.79s	remaining: 117ms
# 983:	learn: 0.0183666	total: 6.8s	remaining: 111ms
# 984:	learn: 0.0183552	total: 6.8s	remaining: 104ms
# 985:	learn: 0.0183427	total: 6.81s	remaining: 96.7ms
# 986:	learn: 0.0182979	total: 6.82s	remaining: 89.8ms
# 987:	learn: 0.0182820	total: 6.82s	remaining: 82.9ms
# 988:	learn: 0.0182419	total: 6.83s	remaining: 76ms
# 989:	learn: 0.0182194	total: 6.84s	remaining: 69.1ms
# 990:	learn: 0.0181840	total: 6.84s	remaining: 62.1ms
# 991:	learn: 0.0181546	total: 6.85s	remaining: 55.2ms
# 992:	learn: 0.0181217	total: 6.86s	remaining: 48.3ms
# 993:	learn: 0.0180657	total: 6.86s	remaining: 41.4ms
# 994:	learn: 0.0180480	total: 6.87s	remaining: 34.5ms
# 995:	learn: 0.0180142	total: 6.88s	remaining: 27.6ms
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:17<00:00,  3.85s/it]
# 996:	learn: 0.0180021	total: 6.88s	remaining: 20.7ms
# 997:	learn: 0.0179748	total: 6.89s	remaining: 13.8ms
# 998:	learn: 0.0179380	total: 6.9s	remaining: 6.9ms
# 999:	learn: 0.0179162	total: 6.9s	remaining: 0us
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5079248218ba> in <module>
#      14         best_clf = clf
#      15     f1_scores.append(score)
# ---> 16 plt.plot(num_est, f1_scores)
#      17 plt.xlabel('n_estimators')
#      18 plt.ylabel('f1-score')
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (20,)

# %%
num_est = range(50, 1001, 50)
plt.plot(num_est, f1_scores)
plt.xlabel('n_estimators')
plt.ylabel('f1-score')
plt.title("Tuning of n_estimators parameter")
# Out:
# Text(0.5, 1.0, 'Tuning of n_estimators parameter')

# %%
print("N-estimators={}".format(best_n_est))
y_pred = best_clf.predict(X_test)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="catboost"))
# Out:
# N-estimators=700
# f1-score=0.9769301753306675
# GBM :
#              precision    recall  f1-score   support
#
#         0.0    0.95450   0.85637   0.90277      2033
#         1.0    0.96453   0.98965   0.97693      8023
#
# avg / total    0.96250   0.96271   0.96194     10056
# final score    0.95951   0.92301   0.93985     10056

# %% [markdown]
# ### lightgbm

# %%
import lightgbm as lgb

train_data = lgb.Dataset(X_train, label=y_train)

# %%
param = {'objective': 'binary', 'metric':'auc'}

f1_scores = []
best_score = 0
best_n_est = 0
best_clf = None

for i in tqdm(range(50, 1001, 50)):
    
    clf = lgb.train(param, train_data, i)
    y_pred = np.where(clf.predict(X_test) < 0.5, 0, 1)
    score = f1_score(y_test, y_pred)
    if best_score < score:
        best_score = score
        best_n_est = i
        best_clf = clf
    f1_scores.append(score)
# Out:
#   5%|████▏                                                                              | 1/20 [00:00<00:02,  6.73it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  10%|████████▎                                                                          | 2/20 [00:00<00:03,  5.44it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003921 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  15%|████████████▍                                                                      | 3/20 [00:00<00:04,  4.01it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  20%|████████████████▌                                                                  | 4/20 [00:01<00:05,  3.01it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002582 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  25%|████████████████████▊                                                              | 5/20 [00:02<00:06,  2.29it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  30%|████████████████████████▉                                                          | 6/20 [00:02<00:07,  1.87it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002712 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
#  35%|█████████████████████████████                                                      | 7/20 [00:03<00:08,  1.58it/s]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#  40%|█████████████████████████████████▏                                                 | 8/20 [00:04<00:08,  1.39it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004999 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#  45%|█████████████████████████████████████▎                                             | 9/20 [00:05<00:08,  1.23it/s]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001444 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#  50%|█████████████████████████████████████████                                         | 10/20 [00:06<00:09,  1.09it/s]
# [LightGBM] [Info] Number of positive: 4123, number of negative: 2970
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003004 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18975
# [LightGBM] [Info] Number of data points in the train set: 7093, number of used features: 98
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.581277 -> initscore=0.328019
# [LightGBM] [Info] Start training from score 0.328019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:19<00:00,  1.02it/s]

# %%
num_est = range(50, 1001, 50)
plt.plot(num_est, f1_scores)
plt.xlabel('n_estimators')
plt.ylabel('f1-score')
plt.title("Tuning of n_estimators parameter")
# Out:
# Text(0.5, 1.0, 'Tuning of n_estimators parameter')

# %%
print("N-estimators={}".format(best_n_est))
y_pred = np.where(best_clf.predict(X_test) < 0.5, 0, 1)
print("f1-score={}".format(f1_score(y_test, y_pred)))
print(classification_report(y_test, y_pred, alg_name="light gbm"))
# Out:
# N-estimators=1000
# f1-score=0.9723618090452262
# GBM :
#              precision    recall  f1-score   support
#
#         0.0    0.86892   0.92277   0.89504      2033
#         1.0    0.98012   0.96473   0.97236      8023
#
# avg / total    0.95764   0.95625   0.95673     10056
# final score    0.92452   0.94375   0.93370     10056

# %% [markdown]
# ### Сравнение качества разных алгоритмов.
#
# *total f1-score* - это f1-score, подсчитанный на всех данных.
#
# *mean f1-score for classes* - это среднее между f1-score для классов спам и неспам.
#
# | Algorithm | total f1-score | mean f1-score for classes |
# | --- | --- | --- |
# | Logistic regression | 0.9360 | 0.8666 |
# | SVM | 0.9585 | 0.9095|
# | Perceptron | 0.9389 | 0.8700 |
# | Random forest | 0.9656 | 0.9196 |
# | Adaboost | 0.9690 | 0.9210 |
# | GBM | 0.9698 | 0.9264 |
# | xgboost | 0.9670 | 0.9095 |
# | dart | 0.9669 | 0.9096 |
# | catboost | 0.9769 | 0.93985 |
# | Light GBM | 0.9723 | 0.9337 |
#
# catboost показал самые лучшие результаты.

# %% [markdown]
# ## ЗАДАНИЕ II. ОСНОВНОЕ

# %%
def ComputeMyTaskNumber(your_name):
    return 1 + hash(your_name) % 21
ComputeMyTaskNumber("Vakulenko_Yulia")
# Out:
# 4

# %% [markdown]
# Моё задание - 4. Реализация алгоритма градиентного бустинга с логистической функцией потерь. В качестве базового алгоритма использовать алгоритм CART (задача классификации).
#
# Модель взвешенного голосования:
#
# $$h(x) = \sum_{i=1}^{T}b_i a_i(x), x\in X, b_i\in R $$
#
# Ошибка композиции на обучающей выборке:
#
# $$error = \sum_{j=1}^{N} L(y_j,\sum_{i=1}^{T-1}b_i a_i(x_j) + b a(x_j))$$
#
# Логистическая функция потерь:
#
# $$L(h) = \sum_{j=1}^{N} (-y_j \log f(x_j) - (1 - y_j)\log (1 - f(x_j)))$$
#
# $$f(x_j) = \sigma (h(x_j)) = \frac{1}{1 + \exp^{-h(x_j)}}$$
#
# Рассчитаем антиградиент лосс-функции. Введем обозначение $h(x_j) = h_j $.
#
# Производная сигмоиды:
# $$\sigma(h)^{'} = \sigma(h)(1 - \sigma(h))$$
#
# Градиент:
# $$\frac{\partial L(y_j, h(x_j))}{\partial h(x_j)} =  \frac{}{\partial h_j} (\sum_{k=1}^{N}(-y_k \log \sigma(h_k)  - (1 - y_k)\log (1 - \sigma(h_j)))) = \frac{}{\partial h(x_j)} (-y_j \log \sigma(h_j) - (1 - y_j)\log (1 - \sigma(h_j))) =  -y_j \frac{\sigma(h_j)(1 - \sigma(h_j))}{\sigma(h_j)} - (1 - y_j)\frac{-\sigma(h_j)(1-\sigma(h_j))}{1-\sigma(h_j)} = -y_j(1 - \sigma(h_j)) + (1 - y_j)\sigma(h_j) = \sigma(h_j) - y_j$$
#
# Антиградиент функции потерь:
# $$ -\frac{\partial L(y_j, h(x_j))}{\partial h(x_j)} = y_j - \sigma(h(x_j))$$
#
# Для нахождения коэффициента $b = argmin_b \sum_{j=1}^{N}L(y_j, h_{i-1}(x)+ b a_i(x))$ воспользуемся методом Ньютона.
#
#
# $$f' = \frac {\partial L}{\partial b} = \sum_{j=1}^{N} a(x_j) (y_j - \sigma (h_{i-1}(x_j) + b a(x_j)))$$
# $$f'' = \frac {\partial^2 L}{\partial b^2} = \sum_{j=1}^{N} a^2(x_j) \sigma(1 - \sigma)$$
#
# $$b_k = b_{k-1} - \frac{f'}{f''}$$

# %%
# Classification and regression tree
class CART():
    def __init__(self, max_depth=3):
        self.max_depth = max_depth
        # left child
        self.left = None
        # right child
        self.right = None
        # index of feature that is used to divide samples
        self.feature_idx = -1
        self.feature_threshold = 0
        # value in leaf
        self.value = 0
        self.criterion = 'mse'
    
    def __mse(self, y):
        return ((y - y.mean()) ** 2).sum()
    
    def error(self, y):
        if self.criterion == 'mse':
            return self.__mse(y)
        
        
    def fit(self, X, y):
        self.value = y.mean()
        
        #print(self.max_depth, self.value)
        
        #stopping criterion
        if self.max_depth < 1:
            return
        
        n_samples = X.shape[0]
        
        best_impurity = None
        error = self.error(y)

        #finding feature for split
        for f in range(X.shape[1]):
            #print(self.feature_idx, best_impurity)
            # indices of samples sorted by value of feature f
            idxs = np.argsort(X[:, f])
            
            # sum of y_true values in fraction of samples
            sum_left = y.sum()
            sum_right = 0

            # number of samples in left and right subtrees
            N_left, N_right = n_samples, 0
            
            #threshold feature's serial number 
            thres = 0
            
            # finding best value of feature f to split 
            while thres < n_samples - 1:
                N_left -= 1
                N_right += 1
                
                # sample with feature index thres
                idx = idxs[thres]
                
                # value of object with idx index
                x = X[idx, f]
                
                sum_left -= y[idx]
                sum_right += y[idx]
                        
                new_error = -((sum_left - sum_left/N_left)**2)/N_left - ((sum_right - sum_right/N_right)**2)/N_right
                
                # equal values of feature
                if thres < n_samples - 1 and x == X[idxs[thres + 1], f]:
                    thres += 1
                    continue

                if self.feature_idx == -1 or new_error < best_impurity:
                    self.feature_idx = f
                    self.feature_threshold = (X[idx, f] + X[idxs[thres + 1], f])/2
                    best_impurity = new_error
                thres += 1
        if self.feature_idx == -1:
            return
        
        # indices for left and right subsamples
        idxs_l = (X[:, self.feature_idx] > self.feature_threshold)
        idxs_r = (X[:, self.feature_idx] <= self.feature_threshold)
    
        #print("feature index = {}, feature threshold = {}".format(self.feature_idx, self.feature_threshold))
        #print("best impurity = {}".format(best_impurity))
        # recursively finds best splits for left and right subtrees
        self.left = CART(self.max_depth - 1)
        self.left.value = y[idxs_l].mean()
        self.right = CART(self.max_depth - 1)
        self.left.value = y[idxs_r].mean()
        
        
    
        self.left.fit(X[idxs_l, :], y[idxs_l])
        self.right.fit(X[idxs_r, :], y[idxs_r])

        
    def __predict(self, x):
        if self.feature_idx == -1:
            return self.value
        
        if x[self.feature_idx] > self.feature_threshold:
            return self.left.__predict(x)
        else:
            return self.right.__predict(x)
        
    def predict(self, X):
        y = np.zeros(X.shape[0])
        
        for i in range(X.shape[0]):
            y[i] = self.__predict(X[i])
            
        return y

# %%
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

clf = DecisionTreeRegressor(max_depth=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 0.12446198984602179

# %%
myclf = CART(max_depth=1)
myclf.fit(X_train, y_train)
y_pred2 = myclf.predict(X_test)
mean_squared_error(y_test, y_pred2)
# Out:
# 0.12446198984602179

# %%
class GBM:
    
    #threshold for classification
    THR = 0.5
    
    def __init__(self, n_estimators=100, learning_rate=0.01, max_depth=3, base_model=CART):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.learning_rate = learning_rate
        self.base_model = base_model
        
        # coefficients for estimators
        self.b = []
        # list with estimators
        self.a = []
        
        self.staged_losses = []

    # logistic fuction
    def __sigmoid(self, h):
        return 1/(1 + np.exp(-h))

    def __negative_grad(self, y, h):
        return  (y - self.__sigmoid(h))
    
    def __log_loss(self, y, y_pred):
        
        sigma = self.__sigmoid(y_pred)
        loss = np.sum(-y*np.log(sigma) - (1 - y)*np.log(1-sigma))
        
        return loss
    
    def calc_b_i(self, h, a, y):
        b = 0
        f1 = 10
        eps = 0.001

        while np.abs(f1) > eps:
            Hba = h + b * a
            sigma = self.__sigmoid(Hba)
            # first derivative
            f1 = np.sum(a*(sigma - y))
            # second derivative
            f2 = np.sum(a*a*sigma*(1-sigma))
            delta = f1/f2
            b = b - delta

        return b
    
    def fit(self, X, y):
        # initial prediction is set to be zeros
        h = np.zeros(y.shape[0])
        
        for i in tqdm(range(self.n_estimators)):
            #print(i)
            # vector with antigradients
            g_i = self.__negative_grad(y, h)
            #print('neg_grad = {}'.format(g_i))
            # i-th estimator
            a_i = self.base_model(max_depth=self.max_depth)
            a_i.fit(X, g_i)
            #prediction of i-th estimator
            a_i_pred = a_i.predict(X)
            #print("y_pred={}".format(h))
            #print("y_pred_new={}".format(a_i_pred))
            
            #coefficient for new estimator
            b_i = self.calc_b_i(h, a_i_pred, y) * self.learning_rate
            #print('b_i={}'.format(b_i))
            self.b.append(b_i)
            self.a.append(a_i)
            
            h = h + b_i * a_i_pred
            
            self.staged_losses.append(self.__log_loss(y, h))
        return self
    
    def predict(self, X):
        y_pred_proba = self.predict_proba(X)
        y_pred = np.where(y_pred_proba < self.__class__.THR, 0, 1)
        return y_pred
    
    def predict_proba(self, X):
        y_pred = np.zeros(X.shape[0])
        for i in range(self.n_estimators):
            y_pred = y_pred + self.b[i] * self.a[i].predict(X)
        return self.__sigmoid(y_pred)
        
    def predict_all_steps(self, X):
        y_preds = [None] * self.n_estimators
        y_pred = np.zeros(X.shape[0])
        for i in range(self.n_estimators):
            y_pred = y_pred + self.b[i] * self.a[i].predict(X)
            y_preds[i] = np.where(self.__sigmoid(y_pred) < self.__class__.THR, 0, 1)
        return y_preds

# %%
my_gb = GBM(learning_rate=0.1, n_estimators=150, 
                         base_model=CART, max_depth=1)
my_gb.fit(X_train, y_train)
y_pred_my = my_gb.predict(X_test)
f1_score(y_test, y_pred_my)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [05:16<00:00,  2.11s/it]
# 0.9684771164922276

# %%
clf = GradientBoostingClassifier(learning_rate=0.1, n_estimators=150, 
                                 max_depth=1, criterion='mse')
clf.fit(X_train, y_train)
y_pred_sk = clf.predict(X_test)
f1_score(y_test, y_pred_sk)
# Out:
# 0.9674154529745742

# %%
my_pred_train = my_gb.predict_all_steps(X_train)
my_pred_test = my_gb.predict_all_steps(X_test)

# %%
def plot_comp_scores(sk_scores, my_scores, title):
    # Plot for comparison of scores from sklearn and mine clfs
    n = len(sk_scores)
    x = np.arange(1,n+1)
    
    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.plot(x, sk_scores, 'm-', label='sklearn test')
    plt.plot(x, my_scores , 'c-', label='my gbm test')
    plt.plot(x, [s * 1.03 for s in sk_scores], 'm-', linestyle='--')
    plt.plot(x, [s * 0.97 for s in sk_scores], 'm-', linestyle='--')
    plt.legend(loc='best')
    plt.xlabel('Iterations')
    plt.ylabel('f1-score')

    print("sklearn f1-score = {:.4f}".format(sk_scores[-1]))
    print("threshold 3% = {:.4f}..{:.4f}".format(0.97 * sk_scores[-1], 1.03 * sk_scores[-1]))
    print("my f1-score = {:.4f}".format(my_scores[-1]))

# %%
n_est = 150

sk_test_scores = np.zeros(n_est)
sk_train_scores = np.zeros(n_est)

my_test_scores = np.zeros(n_est)
my_train_scores = np.zeros(n_est)



for i, y_pred in enumerate(clf.staged_decision_function(X_train)):
    sk_train_scores[i] = f1_score(y_train, np.where(my_gb._GBM__sigmoid(y_pred) < 0.5, 0, 1))
    
for i, y_pred in enumerate(clf.staged_decision_function(X_test)):
    sk_test_scores[i] = f1_score(y_test, np.where(my_gb._GBM__sigmoid(y_pred) < 0.5, 0, 1))

    

for i, y_pred in enumerate(my_pred_train):
    my_train_scores[i] = f1_score(y_train, y_pred)    
    
for i, y_pred in enumerate(my_pred_test):
    my_test_scores[i] = f1_score(y_test, y_pred)

# %%
plot_comp_scores(sk_train_scores, my_train_scores, 'Train comparison')
# Out:
# sklearn f1-score = 0.9598
# threshold 3% = 0.9310..0.9886
# my f1-score = 0.9615

# %%
plot_comp_scores(sk_test_scores, my_test_scores, 'Test comparison')
# Out:
# sklearn f1-score = 0.9674
# threshold 3% = 0.9384..0.9964
# my f1-score = 0.9685
